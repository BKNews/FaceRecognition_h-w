# %% [markdown]
# # A custom facial recognition system
#
# Once upon a time the NYT [built a system to recognize members of Congress](https://open.nytimes.com/how-the-new-york-times-uses-software-to-recognize-members-of-congress-29b46dd426c7). If they can do it, why not us?
#
# ## Obtaining the data
#
# To train a model to recognize members of Congress, we need *labeled pictures of members of Congress.* Luckily I spent a million years doing that for you!
#
# Since I haven't memorized everyone in Congress, I started with a [a list of members of legislators downloaded from GitHub](https://github.com/unitedstates/congress-legislators).

# %%
import pandas as pd
df = pd.read_csv("https://theunitedstates.io/congress-legislators/legislators-current.csv")
df.head()
# Out:
#   last_name first_name  ... icpsr_id    wikipedia_id
# 0     Brown    Sherrod  ...  29389.0   Sherrod Brown
# 1  Cantwell      Maria  ...  39310.0  Maria Cantwell
# 2    Cardin   Benjamin  ...  15408.0      Ben Cardin
# 3    Carper     Thomas  ...  15015.0      Tom Carper
# 4     Casey     Robert  ...  40703.0   Bob Casey Jr.
#
# [5 rows x 34 columns]

# %% [markdown]
# For each row, I combined their first and last name and used [Google Images Downloader](https://github.com/hardikvasa/google-images-download) to search Google Image Search for their name and download 30 images. Each image is stored in a folder named after the Congressperson.
#
# ```
# downloads/
# ├─ congressperson_xyz/
# │  ├─ 1.jpg
# │  ├─ 2.jpg
# │  ├─ 3.jpg
# ├─ congressperson_abc/
#    ├─ 1.jpg
#    ├─ 2.jpg
#    ├─ 3.jpg
# ...
# ```
# That ended up with about 8GB of images, which I then resized using [ImageMagick](https://imagemagick.org/) to a max size of 1080x1080. I guess some of the pictures were very high-res, that got us down to around 2GB.
#
# ### Just the faces, please
#
# Since human beings change their clothes each day, the *face* is the thing that allows us to tell different people apart. So I then ran each image through [MTCNN](https://github.com/ipazc/mtcnn) to cut out the faces and save them separately. So if we had an image with four faces in it, now we have four separate images instead.
#
# For a single member of Congress, all of the faces we found in all of the images of them are stored in a folder named after them.
#
# ```
# faces/
# ├─ congressperson_xyz/
# │  ├─ 1_face0.jpg
# │  ├─ 1_face1.jpg
# │  ├─ 2_face0.jpg
# │  ├─ 3_face0.jpg
# │  ├─ 3_face1.jpg
# │  ├─ 3_face2.jpg
# ├─ congressperson_abc/
#    ├─ 1_face0.jpg
#    ├─ 2_face0.jpg
#    ├─ 2_face1.jpg
#    ├─ 3_face0.jpg
# ...
# ```
#
# ## Pull in the data
#
# Start by downloading [faces.zip](https://drive.google.com/file/d/1-26HtaU6_PfJm-FizHSgJpUh_KRPO60S/view?usp=sharing), then uploading it to your Google Drive.
#
# Then, to import the data into this notebook, we'll need to connect Google Colab to Google Drive.

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# This code connects our Google Drive to the `gdrive` folder. The actual contents of your Google Drive will be in `grdrive/MyDrive`.
#
# Now we can copy `faces.zip` over and unzip it.

# %%
# Copy faces.zip into the current folder
# !cp /content/gdrive/MyDrive/faces.zip .

# Unzip it
# !unzip faces.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: faces/katherine_cammack/0_face_4.5e5e848263454.image.jpg
#   inflating: __MACOSX/faces/katherine_cammack/._0_face_4.5e5e848263454.image.jpg
#   inflating: faces/katherine_cammack/0_face_14.bd5846ed-86f2-4c80-8be1-4e16034ded12-kat_cammack.jpg
#   inflating: __MACOSX/faces/katherine_cammack/._0_face_14.bd5846ed-86f2-4c80-8be1-4e16034ded12-kat_cammack.jpg
#   inflating: faces/katherine_cammack/1_face_25.1517464467811.jpg
#   inflating: __MACOSX/faces/katherine_cammack/._1_face_25.1517464467811.jpg
#   inflating: faces/katherine_cammack/0_face_17.300px-cammack-76.jpg
#   inflating: __MACOSX/faces/katherine_cammack/._0_face_17.300px-cammack-76.jpg
#   inflating: faces/katherine_cammack/0_face_9.oc-brideshero-katherine-cammack1.jpg
#   inflating: __MACOSX/faces/katherine_cammack/._0_face_9.oc-brideshero-katherine-cammack1.jpg
#   inflating: faces/katherine_cammack/0_face_2.katcammack.jpg
#   inflating: __MACOSX/faces/katherine_cammack/._0_face_2.katcammack.jpg
#   inflating: faces/katherine_cammack/7_face_26.great-futures-start-here-iwanttobe_original_24b29987298799fd5958ee94fc77ff18db69c940752d20e3ec3f39074d77737b_social.jpg
#   inflating: __MACOSX/faces/katherine_cammack/._7_face_26.great-futures-start-here-iwanttobe_original_24b29987298799fd5958ee94fc77ff18db69c940752d20e3ec3f39074d77737b_social.jpg
#   inflating: faces/katherine_cammack/0_face_18.48622795_1407446470.jpg
#   inflating: __MACOSX/faces/katherine_cammack/._0_face_18.48622795_1407446470.jpg
#   inflating: faces/katherine_cammack/4_face_26.great-futures-start-here-iwanttobe_original_24b29987298799fd5958ee94fc77ff18db69c940752d20e3ec3f39074d77737b_social.jpg
#   inflating: __MACOSX/faces/katherine_cammack/._4_face_26.great-futures-start-here-iwanttobe_original_24b29987298799fd5958ee94fc77ff18db69c940752d20e3ec3f39074d77737b_social.jpg
#   inflating: faces/katherine_cammack/0_face_6.portraitfull-sml-mg-1386.jpg
#   inflating: __MACOSX/faces/katherine_cammack/._0_face_6.portraitfull-sml-mg-1386.jpg
#   inflating: faces/bradley_schneider/4_face_24.class%20of%202023.jpg
#   inflating: __MACOSX/faces/bradley_schneider/._4_face_24.class%20of%202023.jpg
#   inflating: faces/bradley_schneider/0_face_12.getimagejpeg.ashx.jpg
#   inflating: __MACOSX/faces/bradley_schneider/._0_face_12.getimagejpeg.ashx.jpg
#   inflating: faces/bradley_schneider/2_face_17.sjmsytmwz5dnxaotcw4exyyrze.jpg
#   inflating: __MACOSX/faces/bradley_schneider/._2_face_17.sjmsytmwz5dnxaotcw4exyyrze.jpg
#   inflating: faces/bradley_schneider/1_face_17.sjmsytmwz5dnxaotcw4exyyrze.jpg
#   inflating: __MACOSX/faces/bradley_schneider/._1_face_17.sjmsytmwz5dnxaotcw4exyyrze.jpg
#   inflating: faces/bradley_schneider/1_face_28.ct-1541564989-9242mjbsoe-snap-image.jpg
#   inflating: __MACOSX/faces/bradley_schneider/._1_face_28.ct-1541564989-9242mjbsoe-snap-image.jpg
#   inflating: faces/bradley_schneider/5_face_28.ct-1541564989-9242mjbsoe-snap-image.jpg
#   inflating: __MACOSX/faces/bradley_schneider/._5_face_28.ct-1541564989-9242mjbsoe-snap-image.jpg
#   inflating: faces/bradley_schneider/3_face_24.class%20of%202023.jpg
#   inflating: __MACOSX/faces/bradley_schneider/._3_face_24.class%20of%202023.jpg
#   inflating: faces/bradley_schneider/0_face_9.5178ae14a52c6.image.jpg
#   inflating: __MACOSX/faces/bradley_schneider/._0_face_9.5178ae14a52c6.image.jpg
#   inflating: faces/bradley_schneider/0_face_18.1517767191690.jpg
#   inflating: __MACOSX/faces/bradley_schneider/._0_face_18.1517767191690.jpg
#   inflating: faces/bradley_schneider/0_face_19.img_6201-900x600.jpg
#   inflating: __MACOSX/faces/bradley_schneider/._0_face_19.img_6201-900x600.jpg
#   inflating: faces/bradley_schneider/4_face_28.ct-1541564989-9242mjbsoe-snap-image.jpg
#   inflating: __MACOSX/faces/bradley_schneider/._4_face_28.ct-1541564989-9242mjbsoe-snap-image.jpg
#   inflating: faces/bradley_schneider/0_face_3.k93gj-ob_400x400.jpg
#   inflating: __MACOSX/faces/bradley_schneider/._0_face_3.k93gj-ob_400x400.jpg
#   inflating: faces/bradley_schneider/0_face_28.ct-1541564989-9242mjbsoe-snap-image.jpg
#   inflating: __MACOSX/faces/bradley_schneider/._0_face_28.ct-1541564989-9242mjbsoe-snap-image.jpg
#   inflating: faces/bradley_schneider/1_face_22.yzsyaoqt.jpg
#   inflating: __MACOSX/faces/bradley_schneider/._1_face_22.yzsyaoqt.jpg
#   inflating: faces/bradley_schneider/0_face_1.brad%20schneider%20-%20il-10.jpg
#   inflating: __MACOSX/faces/bradley_schneider/._0_face_1.brad%20schneider%20-%20il-10.jpg
#   inflating: faces/bradley_schneider/1_face_16.13466541_10209930557726276_2768210348953557572_n1.jpg
#   inflating: __MACOSX/faces/bradley_schneider/._1_face_16.13466541_10209930557726276_2768210348953557572_n1.jpg
#   inflating: faces/bradley_schneider/1_face_26.2ecgnuluvje55ncm53cxpxskam.jpg
#   inflating: __MACOSX/faces/bradley_schneider/._1_face_26.2ecgnuluvje55ncm53cxpxskam.jpg
#   inflating: faces/bradley_schneider/0_face_15.preview.jpg
#   inflating: __MACOSX/faces/bradley_schneider/._0_face_15.preview.jpg
#   inflating: faces/bradley_schneider/3_face_28.ct-1541564989-9242mjbsoe-snap-image.jpg
#   inflating: __MACOSX/faces/bradley_schneider/._3_face_28.ct-1541564989-9242mjbsoe-snap-image.jpg
#   inflating: faces/bradley_schneider/0_face_20.web-fn-schneider-0.jpg
#   inflating: __MACOSX/faces/bradley_schneider/._0_face_20.web-fn-schneider-0.jpg
#   inflating: faces/bradley_schneider/0_face_13.bradley_schneider.jpg
#   inflating: __MACOSX/faces/bradley_schneider/._0_face_13.bradley_schneider.jpg
#   inflating: faces/bradley_schneider/0_face_23.screen_shot_2021_01_12_at_2.07.42_pm.png.jpg
#   inflating: __MACOSX/faces/bradley_schneider/._0_face_23.screen_shot_2021_01_12_at_2.07.42_pm.png.jpg
#   inflating: faces/bradley_schneider/0_face_8.86347623_10217317914241988_1862323576464474112_o-bradley-schneider-copy.jpg
#   inflating: __MACOSX/faces/bradley_schneider/._0_face_8.86347623_10217317914241988_1862323576464474112_o-bradley-schneider-copy.jpg
#   inflating: faces/bradley_schneider/5_face_24.class%20of%202023.jpg
#   inflating: __MACOSX/faces/bradley_schneider/._5_face_24.class%20of%202023.jpg
#   inflating: faces/bradley_schneider/2_face_28.ct-1541564989-9242mjbsoe-snap-image.jpg
#   inflating: __MACOSX/faces/bradley_schneider/._2_face_28.ct-1541564989-9242mjbsoe-snap-image.jpg
#   inflating: faces/bradley_schneider/0_face_22.yzsyaoqt.jpg
#   inflating: __MACOSX/faces/bradley_schneider/._0_face_22.yzsyaoqt.jpg
#   inflating: faces/bradley_schneider/0_face_25.1517283870218.jpg
#   inflating: __MACOSX/faces/bradley_schneider/._0_face_25.1517283870218.jpg
#   inflating: faces/bradley_schneider/0_face_29.bradley-schneider.jpg
#   inflating: __MACOSX/faces/bradley_schneider/._0_face_29.bradley-schneider.jpg
#   inflating: faces/bradley_schneider/0_face_10.s001190.jpg
#   inflating: __MACOSX/faces/bradley_schneider/._0_face_10.s001190.jpg
#   inflating: faces/bradley_schneider/0_face_21.schneider_brad.jpg
#   inflating: __MACOSX/faces/bradley_schneider/._0_face_21.schneider_brad.jpg
#   inflating: faces/bradley_schneider/2_face_24.class%20of%202023.jpg
#   inflating: __MACOSX/faces/bradley_schneider/._2_face_24.class%20of%202023.jpg
#   inflating: faces/bradley_schneider/0_face_14.bradley-schneider.jpg
#   inflating: __MACOSX/faces/bradley_schneider/._0_face_14.bradley-schneider.jpg
#   inflating: faces/bradley_schneider/0_face_11.rpfgah1g_400x400.jpg
#   inflating: __MACOSX/faces/bradley_schneider/._0_face_11.rpfgah1g_400x400.jpg
#   inflating: faces/bradley_schneider/3_face_22.yzsyaoqt.jpg
#   inflating: __MACOSX/faces/bradley_schneider/._3_face_22.yzsyaoqt.jpg
#   inflating: faces/bradley_schneider/0_face_27.uvc_all_championship_1920x1080.jpg
#   inflating: __MACOSX/faces/bradley_schneider/._0_face_27.uvc_all_championship_1920x1080.jpg
#   inflating: faces/bradley_schneider/0_face_30.schneider-brad-1528446796.jpg
#   inflating: __MACOSX/faces/bradley_schneider/._0_face_30.schneider-brad-1528446796.jpg
#   inflating: faces/bradley_schneider/1_face_24.class%20of%202023.jpg
#   inflating: __MACOSX/faces/bradley_schneider/._1_face_24.class%20of%202023.jpg
#   inflating: faces/bradley_schneider/0_face_2.412534-200px.jpeg
#   inflating: __MACOSX/faces/bradley_schneider/._0_face_2.412534-200px.jpeg
#   inflating: faces/bradley_schneider/2_face_27.uvc_all_championship_1920x1080.jpg
#   inflating: __MACOSX/faces/bradley_schneider/._2_face_27.uvc_all_championship_1920x1080.jpg
#   inflating: faces/bradley_schneider/0_face_4.1556666640640.jpg
#   inflating: __MACOSX/faces/bradley_schneider/._0_face_4.1556666640640.jpg
#   inflating: faces/bradley_schneider/0_face_26.2ecgnuluvje55ncm53cxpxskam.jpg
#   inflating: __MACOSX/faces/bradley_schneider/._0_face_26.2ecgnuluvje55ncm53cxpxskam.jpg
#   inflating: faces/bradley_schneider/6_face_24.class%20of%202023.jpg
#   inflating: __MACOSX/faces/bradley_schneider/._6_face_24.class%20of%202023.jpg
#   inflating: faces/bradley_schneider/0_face_24.class%20of%202023.jpg
#   inflating: __MACOSX/faces/bradley_schneider/._0_face_24.class%20of%202023.jpg
#   inflating: faces/bradley_schneider/2_face_22.yzsyaoqt.jpg
#   inflating: __MACOSX/faces/bradley_schneider/._2_face_22.yzsyaoqt.jpg
#   inflating: faces/bradley_schneider/0_face_5.07292013_repschneider.ashx.jpg
#   inflating: __MACOSX/faces/bradley_schneider/._0_face_5.07292013_repschneider.ashx.jpg
#   inflating: faces/bradley_schneider/1_face_27.uvc_all_championship_1920x1080.jpg
#   inflating: __MACOSX/faces/bradley_schneider/._1_face_27.uvc_all_championship_1920x1080.jpg
#   inflating: faces/bradley_schneider/0_face_6.schneiderbrad_111516gn_lead.jpg
#   inflating: __MACOSX/faces/bradley_schneider/._0_face_6.schneiderbrad_111516gn_lead.jpg
#   inflating: faces/bradley_schneider/0_face_16.13466541_10209930557726276_2768210348953557572_n1.jpg
#   inflating: __MACOSX/faces/bradley_schneider/._0_face_16.13466541_10209930557726276_2768210348953557572_n1.jpg
#   inflating: faces/bradley_schneider/0_face_7.bradley_scneider_edited1.jpg
#   inflating: __MACOSX/faces/bradley_schneider/._0_face_7.bradley_scneider_edited1.jpg
#   inflating: faces/bradley_schneider/3_face_27.uvc_all_championship_1920x1080.jpg
#   inflating: __MACOSX/faces/bradley_schneider/._3_face_27.uvc_all_championship_1920x1080.jpg
#   inflating: faces/bradley_schneider/7_face_24.class%20of%202023.jpg
#   inflating: __MACOSX/faces/bradley_schneider/._7_face_24.class%20of%202023.jpg
#   inflating: faces/bradley_schneider/0_face_17.sjmsytmwz5dnxaotcw4exyyrze.jpg
#   inflating: __MACOSX/faces/bradley_schneider/._0_face_17.sjmsytmwz5dnxaotcw4exyyrze.jpg
#   inflating: faces/bradley_schneider/8_face_24.class%20of%202023.jpg
#   inflating: __MACOSX/faces/bradley_schneider/._8_face_24.class%20of%202023.jpg
#   inflating: faces/bradley_schneider/3_face_17.sjmsytmwz5dnxaotcw4exyyrze.jpg
#   inflating: __MACOSX/faces/bradley_schneider/._3_face_17.sjmsytmwz5dnxaotcw4exyyrze.jpg
#   inflating: faces/michael_cloud/0_face_11.07%2020%2018%20michael%20cloud%20headshot%206v3.jpg
#   inflating: __MACOSX/faces/michael_cloud/._0_face_11.07%2020%2018%20michael%20cloud%20headshot%206v3.jpg
#   inflating: faces/michael_cloud/0_face_15.5f3f3e2292b68.image.jpg
#   inflating: __MACOSX/faces/michael_cloud/._0_face_15.5f3f3e2292b68.image.jpg
#   inflating: faces/michael_cloud/1_face_27.5b37c1a04283c.image.jpg
#   inflating: __MACOSX/faces/michael_cloud/._1_face_27.5b37c1a04283c.image.jpg
#   inflating: faces/michael_cloud/0_face_9.5b45436a70150.image.jpg
#   inflating: __MACOSX/faces/michael_cloud/._0_face_9.5b45436a70150.image.jpg
#   inflating: faces/michael_cloud/1_face_28.20180710203330001_hd.jpg
#   inflating: __MACOSX/faces/michael_cloud/._1_face_28.20180710203330001_hd.jpg
#   inflating: faces/michael_cloud/2_face_23.campaign_header_rounded.jpg
#   inflating: __MACOSX/faces/michael_cloud/._2_face_23.campaign_header_rounded.jpg
#   inflating: faces/michael_cloud/1_face_25.eqfvpltxaainfa5.jpg
#   inflating: __MACOSX/faces/michael_cloud/._1_face_25.eqfvpltxaainfa5.jpg
#   inflating: faces/michael_cloud/0_face_1.michael_cloud_115th_congress_2.jpg
#   inflating: __MACOSX/faces/michael_cloud/._0_face_1.michael_cloud_115th_congress_2.jpg
#   inflating: faces/michael_cloud/0_face_26.rep-michael-cloud_1547681270793-jpg_29959832_ver1-0.jpg
#   inflating: __MACOSX/faces/michael_cloud/._0_face_26.rep-michael-cloud_1547681270793-jpg_29959832_ver1-0.jpg
#   inflating: faces/michael_cloud/0_face_13.20180710_200230.jpg
#   inflating: __MACOSX/faces/michael_cloud/._0_face_13.20180710_200230.jpg
#   inflating: faces/michael_cloud/6_face_6.cloud_mock_swear_in_al_tt.jpg
#   inflating: __MACOSX/faces/michael_cloud/._6_face_6.cloud_mock_swear_in_al_tt.jpg
#   inflating: faces/michael_cloud/0_face_17.6e4097e3-e305-465a-bd2c-c9834b527963-congressional_district_2702.jpg
#   inflating: __MACOSX/faces/michael_cloud/._0_face_17.6e4097e3-e305-465a-bd2c-c9834b527963-congressional_district_2702.jpg
#   inflating: faces/michael_cloud/1_face_6.cloud_mock_swear_in_al_tt.jpg
#   inflating: __MACOSX/faces/michael_cloud/._1_face_6.cloud_mock_swear_in_al_tt.jpg
#   inflating: faces/michael_cloud/4_face_25.eqfvpltxaainfa5.jpg
#   inflating: __MACOSX/faces/michael_cloud/._4_face_25.eqfvpltxaainfa5.jpg
#   inflating: faces/michael_cloud/0_face_24.5ae16435-2fae-4741-b7f7-6a05beb734f7_poster.jpg
#   inflating: __MACOSX/faces/michael_cloud/._0_face_24.5ae16435-2fae-4741-b7f7-6a05beb734f7_poster.jpg
#   inflating: faces/michael_cloud/0_face_21.54c2f403-b219-451d-8778-50719bc86c80-air_force_one_with_president_trump.jpg
#   inflating: __MACOSX/faces/michael_cloud/._0_face_21.54c2f403-b219-451d-8778-50719bc86c80-air_force_one_with_president_trump.jpg
#   inflating: faces/michael_cloud/1_face_29.08df72ae-041a-45e0-9daa-1e8375b2d3cc-799918002-port_a_ceremony-007.jpg
#   inflating: __MACOSX/faces/michael_cloud/._1_face_29.08df72ae-041a-45e0-9daa-1e8375b2d3cc-799918002-port_a_ceremony-007.jpg
#   inflating: faces/michael_cloud/1_face_23.campaign_header_rounded.jpg
#   inflating: __MACOSX/faces/michael_cloud/._1_face_23.campaign_header_rounded.jpg
#   inflating: faces/michael_cloud/0_face_30.557087064_750x422.jpg
#   inflating: __MACOSX/faces/michael_cloud/._0_face_30.557087064_750x422.jpg
#   inflating: faces/michael_cloud/0_face_2.michael_cloud.jpg
#   inflating: __MACOSX/faces/michael_cloud/._0_face_2.michael_cloud.jpg
#   inflating: faces/michael_cloud/0_face_6.cloud_mock_swear_in_al_tt.jpg
#   inflating: __MACOSX/faces/michael_cloud/._0_face_6.cloud_mock_swear_in_al_tt.jpg
#   inflating: faces/michael_cloud/0_face_5.w4anaeiq.jpg
#   inflating: __MACOSX/faces/michael_cloud/._0_face_5.w4anaeiq.jpg
#   inflating: faces/michael_cloud/3_face_19.cloudswearin_ss_071018_04.jpg
#   inflating: __MACOSX/faces/michael_cloud/._3_face_19.cloudswearin_ss_071018_04.jpg
#   inflating: faces/michael_cloud/2_face_19.cloudswearin_ss_071018_04.jpg
#   inflating: __MACOSX/faces/michael_cloud/._2_face_19.cloudswearin_ss_071018_04.jpg
#   inflating: faces/michael_cloud/1_face_13.20180710_200230.jpg
#   inflating: __MACOSX/faces/michael_cloud/._1_face_13.20180710_200230.jpg
#   inflating: faces/michael_cloud/1_face_19.cloudswearin_ss_071018_04.jpg
#   inflating: __MACOSX/faces/michael_cloud/._1_face_19.cloudswearin_ss_071018_04.jpg
#   inflating: faces/michael_cloud/4_face_23.campaign_header_rounded.jpg
#   inflating: __MACOSX/faces/michael_cloud/._4_face_23.campaign_header_rounded.jpg
#   inflating: faces/michael_cloud/0_face_19.cloudswearin_ss_071018_04.jpg
#   inflating: __MACOSX/faces/michael_cloud/._0_face_19.cloudswearin_ss_071018_04.jpg
#   inflating: faces/michael_cloud/1_face_9.5b45436a70150.image.jpg
#   inflating: __MACOSX/faces/michael_cloud/._1_face_9.5b45436a70150.image.jpg
#   inflating: faces/michael_cloud/4_face_19.cloudswearin_ss_071018_04.jpg
#   inflating: __MACOSX/faces/michael_cloud/._4_face_19.cloudswearin_ss_071018_04.jpg
#   inflating: faces/michael_cloud/0_face_7.115_rp_tx_27_cloud_michael.jpg
#   inflating: __MACOSX/faces/michael_cloud/._0_face_7.115_rp_tx_27_cloud_michael.jpg
#   inflating: faces/michael_cloud/0_face_25.eqfvpltxaainfa5.jpg
#   inflating: __MACOSX/faces/michael_cloud/._0_face_25.eqfvpltxaainfa5.jpg
#   inflating: faces/michael_cloud/5_face_19.cloudswearin_ss_071018_04.jpg
#   inflating: __MACOSX/faces/michael_cloud/._5_face_19.cloudswearin_ss_071018_04.jpg
#   inflating: faces/michael_cloud/2_face_27.5b37c1a04283c.image.jpg
#   inflating: __MACOSX/faces/michael_cloud/._2_face_27.5b37c1a04283c.image.jpg
#   inflating: faces/michael_cloud/2_face_28.20180710203330001_hd.jpg
#   inflating: __MACOSX/faces/michael_cloud/._2_face_28.20180710203330001_hd.jpg
#   inflating: faces/michael_cloud/0_face_10.cloudforcongress_inthenews_vicad_newcongressmandistrictoffices-1024x585.jpg
#   inflating: __MACOSX/faces/michael_cloud/._0_face_10.cloudforcongress_inthenews_vicad_newcongressmandistrictoffices-1024x585.jpg
#   inflating: faces/michael_cloud/0_face_18.poster_5c59ea36ab3a4c50a518a0da99f4fd74.jpg
#   inflating: __MACOSX/faces/michael_cloud/._0_face_18.poster_5c59ea36ab3a4c50a518a0da99f4fd74.jpg
#   inflating: faces/michael_cloud/0_face_16.c001115.jpg
#   inflating: __MACOSX/faces/michael_cloud/._0_face_16.c001115.jpg
#   inflating: faces/michael_cloud/1_face_30.557087064_750x422.jpg
#   inflating: __MACOSX/faces/michael_cloud/._1_face_30.557087064_750x422.jpg
#   inflating: faces/michael_cloud/2_face_29.08df72ae-041a-45e0-9daa-1e8375b2d3cc-799918002-port_a_ceremony-007.jpg
#   inflating: __MACOSX/faces/michael_cloud/._2_face_29.08df72ae-041a-45e0-9daa-1e8375b2d3cc-799918002-port_a_ceremony-007.jpg
#   inflating: faces/michael_cloud/1_face_21.54c2f403-b219-451d-8778-50719bc86c80-air_force_one_with_president_trump.jpg
#   inflating: __MACOSX/faces/michael_cloud/._1_face_21.54c2f403-b219-451d-8778-50719bc86c80-air_force_one_with_president_trump.jpg
#   inflating: faces/michael_cloud/0_face_20.michael-cloud.jpeg
#   inflating: __MACOSX/faces/michael_cloud/._0_face_20.michael-cloud.jpeg
#   inflating: faces/michael_cloud/3_face_23.campaign_header_rounded.jpg
#   inflating: __MACOSX/faces/michael_cloud/._3_face_23.campaign_header_rounded.jpg
#   inflating: faces/michael_cloud/0_face_22.346bb9cb752a716b3830422c5e6b663cb1b412b4.jpeg
#   inflating: __MACOSX/faces/michael_cloud/._0_face_22.346bb9cb752a716b3830422c5e6b663cb1b412b4.jpeg
#   inflating: faces/michael_cloud/0_face_14.maxresdefault.jpg
#   inflating: __MACOSX/faces/michael_cloud/._0_face_14.maxresdefault.jpg
#   inflating: faces/michael_cloud/2_face_9.5b45436a70150.image.jpg
#   inflating: __MACOSX/faces/michael_cloud/._2_face_9.5b45436a70150.image.jpg
#   inflating: faces/michael_cloud/4_face_9.5b45436a70150.image.jpg
#   inflating: __MACOSX/faces/michael_cloud/._4_face_9.5b45436a70150.image.jpg
#   inflating: faces/michael_cloud/0_face_23.campaign_header_rounded.jpg
#   inflating: __MACOSX/faces/michael_cloud/._0_face_23.campaign_header_rounded.jpg
#   inflating: faces/michael_cloud/3_face_25.eqfvpltxaainfa5.jpg
#   inflating: __MACOSX/faces/michael_cloud/._3_face_25.eqfvpltxaainfa5.jpg
#   inflating: faces/michael_cloud/0_face_12.cloudswearin_ss_071018_01.jpg
#   inflating: __MACOSX/faces/michael_cloud/._0_face_12.cloudswearin_ss_071018_01.jpg
#   inflating: faces/michael_cloud/0_face_4.2019-06-20_ec_0125.jpg
#   inflating: __MACOSX/faces/michael_cloud/._0_face_4.2019-06-20_ec_0125.jpg
#   inflating: faces/michael_cloud/0_face_28.20180710203330001_hd.jpg
#   inflating: __MACOSX/faces/michael_cloud/._0_face_28.20180710203330001_hd.jpg
#   inflating: faces/michael_cloud/2_face_13.20180710_200230.jpg
#   inflating: __MACOSX/faces/michael_cloud/._2_face_13.20180710_200230.jpg
#   inflating: faces/michael_cloud/3_face_28.20180710203330001_hd.jpg
#   inflating: __MACOSX/faces/michael_cloud/._3_face_28.20180710203330001_hd.jpg
#   inflating: faces/michael_cloud/5_face_9.5b45436a70150.image.jpg
#   inflating: __MACOSX/faces/michael_cloud/._5_face_9.5b45436a70150.image.jpg
#   inflating: faces/michael_cloud/2_face_6.cloud_mock_swear_in_al_tt.jpg
#   inflating: __MACOSX/faces/michael_cloud/._2_face_6.cloud_mock_swear_in_al_tt.jpg
#   inflating: faces/michael_cloud/5_face_6.cloud_mock_swear_in_al_tt.jpg
#   inflating: __MACOSX/faces/michael_cloud/._5_face_6.cloud_mock_swear_in_al_tt.jpg
#   inflating: faces/michael_cloud/3_face_9.5b45436a70150.image.jpg
#   inflating: __MACOSX/faces/michael_cloud/._3_face_9.5b45436a70150.image.jpg
#   inflating: faces/michael_cloud/0_face_27.5b37c1a04283c.image.jpg
#   inflating: __MACOSX/faces/michael_cloud/._0_face_27.5b37c1a04283c.image.jpg
#   inflating: faces/michael_cloud/0_face_3.412746-200px.jpeg
#   inflating: __MACOSX/faces/michael_cloud/._0_face_3.412746-200px.jpeg
#   inflating: faces/michael_cloud/5_face_8.i3r7axb4lgwpsbwabf4fnkvfb4.jpg
#   inflating: __MACOSX/faces/michael_cloud/._5_face_8.i3r7axb4lgwpsbwabf4fnkvfb4.jpg
#   inflating: faces/michael_cloud/4_face_8.i3r7axb4lgwpsbwabf4fnkvfb4.jpg
#   inflating: __MACOSX/faces/michael_cloud/._4_face_8.i3r7axb4lgwpsbwabf4fnkvfb4.jpg
#   inflating: faces/michael_cloud/0_face_29.08df72ae-041a-45e0-9daa-1e8375b2d3cc-799918002-port_a_ceremony-007.jpg
#   inflating: __MACOSX/faces/michael_cloud/._0_face_29.08df72ae-041a-45e0-9daa-1e8375b2d3cc-799918002-port_a_ceremony-007.jpg
#   inflating: faces/michael_cloud/0_face_8.i3r7axb4lgwpsbwabf4fnkvfb4.jpg
#   inflating: __MACOSX/faces/michael_cloud/._0_face_8.i3r7axb4lgwpsbwabf4fnkvfb4.jpg
#   inflating: faces/michael_cloud/1_face_4.2019-06-20_ec_0125.jpg
#   inflating: __MACOSX/faces/michael_cloud/._1_face_4.2019-06-20_ec_0125.jpg
#   inflating: faces/michael_cloud/1_face_8.i3r7axb4lgwpsbwabf4fnkvfb4.jpg
#   inflating: __MACOSX/faces/michael_cloud/._1_face_8.i3r7axb4lgwpsbwabf4fnkvfb4.jpg
#   inflating: faces/michael_cloud/2_face_25.eqfvpltxaainfa5.jpg
#   inflating: __MACOSX/faces/michael_cloud/._2_face_25.eqfvpltxaainfa5.jpg
#   inflating: faces/michael_cloud/2_face_8.i3r7axb4lgwpsbwabf4fnkvfb4.jpg
#   inflating: __MACOSX/faces/michael_cloud/._2_face_8.i3r7axb4lgwpsbwabf4fnkvfb4.jpg
#   inflating: faces/michael_cloud/3_face_6.cloud_mock_swear_in_al_tt.jpg
#   inflating: __MACOSX/faces/michael_cloud/._3_face_6.cloud_mock_swear_in_al_tt.jpg
#   inflating: faces/michael_cloud/4_face_6.cloud_mock_swear_in_al_tt.jpg
#   inflating: __MACOSX/faces/michael_cloud/._4_face_6.cloud_mock_swear_in_al_tt.jpg
#   inflating: faces/michael_cloud/3_face_8.i3r7axb4lgwpsbwabf4fnkvfb4.jpg
#   inflating: __MACOSX/faces/michael_cloud/._3_face_8.i3r7axb4lgwpsbwabf4fnkvfb4.jpg
#   inflating: faces/nancy_mace/0_face_1.nancy_mace.jpg
#   inflating: __MACOSX/faces/nancy_mace/._0_face_1.nancy_mace.jpg
#   inflating: faces/nancy_mace/0_face_3.5f1776f6eeff5.image.jpg
#   inflating: __MACOSX/faces/nancy_mace/._0_face_3.5f1776f6eeff5.image.jpg
#   inflating: faces/nancy_mace/2_face_26.nancy-kids-election-night-1024x786.jpg
#   inflating: __MACOSX/faces/nancy_mace/._2_face_26.nancy-kids-election-night-1024x786.jpg
#   inflating: faces/nancy_mace/0_face_17.l7ptnrthcrapni37vkwhp5dswi.jpg
#   inflating: __MACOSX/faces/nancy_mace/._0_face_17.l7ptnrthcrapni37vkwhp5dswi.jpg
#   inflating: faces/nancy_mace/1_face_10.ebdwxt4waaabeoe.jpg:large.jpg
#   inflating: __MACOSX/faces/nancy_mace/._1_face_10.ebdwxt4waaabeoe.jpg:large.jpg
#   inflating: faces/nancy_mace/0_face_15.d88065e9-d632-42b8-b4a2-9cb0a71d0b52-large16x9_nancymacecapitolprotestsinterview.jpg
#   inflating: __MACOSX/faces/nancy_mace/._0_face_15.d88065e9-d632-42b8-b4a2-9cb0a71d0b52-large16x9_nancymacecapitolprotestsinterview.jpg
#   inflating: faces/nancy_mace/0_face_10.ebdwxt4waaabeoe.jpg:large.jpg
#   inflating: __MACOSX/faces/nancy_mace/._0_face_10.ebdwxt4waaabeoe.jpg:large.jpg
#   inflating: faces/nancy_mace/0_face_8.mace.jpg
#   inflating: __MACOSX/faces/nancy_mace/._0_face_8.mace.jpg
#   inflating: faces/nancy_mace/0_face_29.mace-5.jpg
#   inflating: __MACOSX/faces/nancy_mace/._0_face_29.mace-5.jpg
#   inflating: faces/nancy_mace/1_face_23.qaazpdp-asset-mezzanine-16x9-930hcxb.jpg
#   inflating: __MACOSX/faces/nancy_mace/._1_face_23.qaazpdp-asset-mezzanine-16x9-930hcxb.jpg
#   inflating: faces/nancy_mace/3_face_23.qaazpdp-asset-mezzanine-16x9-930hcxb.jpg
#   inflating: __MACOSX/faces/nancy_mace/._3_face_23.qaazpdp-asset-mezzanine-16x9-930hcxb.jpg
#   inflating: faces/nancy_mace/1_face_8.mace.jpg
#   inflating: __MACOSX/faces/nancy_mace/._1_face_8.mace.jpg
#   inflating: faces/nancy_mace/0_face_27.3gpfti5twjbb5ibvflxy5hrxoe.jpg
#   inflating: __MACOSX/faces/nancy_mace/._0_face_27.3gpfti5twjbb5ibvflxy5hrxoe.jpg
#   inflating: faces/nancy_mace/0_face_7.m000194.jpg
#   inflating: __MACOSX/faces/nancy_mace/._0_face_7.m000194.jpg
#   inflating: faces/nancy_mace/0_face_14.yrja7ukpzbd5xlbuzc6i6czc5y.jpg
#   inflating: __MACOSX/faces/nancy_mace/._0_face_14.yrja7ukpzbd5xlbuzc6i6czc5y.jpg
#   inflating: faces/nancy_mace/2_face_13.mace-3-780x1024.jpg
#   inflating: __MACOSX/faces/nancy_mace/._2_face_13.mace-3-780x1024.jpg
#   inflating: faces/nancy_mace/0_face_28.ap20044800309759.jpg
#   inflating: __MACOSX/faces/nancy_mace/._0_face_28.ap20044800309759.jpg
#   inflating: faces/nancy_mace/0_face_26.nancy-kids-election-night-1024x786.jpg
#   inflating: __MACOSX/faces/nancy_mace/._0_face_26.nancy-kids-election-night-1024x786.jpg
#   inflating: faces/nancy_mace/0_face_30.bio.jpg
#   inflating: __MACOSX/faces/nancy_mace/._0_face_30.bio.jpg
#   inflating: faces/nancy_mace/1_face_22.group-shot.jpg
#   inflating: __MACOSX/faces/nancy_mace/._1_face_22.group-shot.jpg
#   inflating: faces/nancy_mace/1_face_28.ap20044800309759.jpg
#   inflating: __MACOSX/faces/nancy_mace/._1_face_28.ap20044800309759.jpg
#   inflating: faces/nancy_mace/3_face_8.mace.jpg
#   inflating: __MACOSX/faces/nancy_mace/._3_face_8.mace.jpg
#   inflating: faces/nancy_mace/6_face_22.group-shot.jpg
#   inflating: __MACOSX/faces/nancy_mace/._6_face_22.group-shot.jpg
#   inflating: faces/nancy_mace/1_face_26.nancy-kids-election-night-1024x786.jpg
#   inflating: __MACOSX/faces/nancy_mace/._1_face_26.nancy-kids-election-night-1024x786.jpg
#   inflating: faces/nancy_mace/0_face_21.800.jpeg
#   inflating: __MACOSX/faces/nancy_mace/._0_face_21.800.jpeg
#   inflating: faces/nancy_mace/1_face_13.mace-3-780x1024.jpg
#   inflating: __MACOSX/faces/nancy_mace/._1_face_13.mace-3-780x1024.jpg
#   inflating: faces/nancy_mace/0_face_19.papp6comw5cophfz7xvndomwb4.png.jpg
#   inflating: __MACOSX/faces/nancy_mace/._0_face_19.papp6comw5cophfz7xvndomwb4.png.jpg
#   inflating: faces/nancy_mace/0_face_23.qaazpdp-asset-mezzanine-16x9-930hcxb.jpg
#   inflating: __MACOSX/faces/nancy_mace/._0_face_23.qaazpdp-asset-mezzanine-16x9-930hcxb.jpg
#   inflating: faces/nancy_mace/5_face_22.group-shot.jpg
#   inflating: __MACOSX/faces/nancy_mace/._5_face_22.group-shot.jpg
#   inflating: faces/nancy_mace/2_face_23.qaazpdp-asset-mezzanine-16x9-930hcxb.jpg
#   inflating: __MACOSX/faces/nancy_mace/._2_face_23.qaazpdp-asset-mezzanine-16x9-930hcxb.jpg
#   inflating: faces/nancy_mace/0_face_6.eq1vlonw4aqarq1.jpg
#   inflating: __MACOSX/faces/nancy_mace/._0_face_6.eq1vlonw4aqarq1.jpg
#   inflating: faces/nancy_mace/1_face_2.5f5b95c85d226.image.jpg
#   inflating: __MACOSX/faces/nancy_mace/._1_face_2.5f5b95c85d226.image.jpg
#   inflating: faces/nancy_mace/2_face_22.group-shot.jpg
#   inflating: __MACOSX/faces/nancy_mace/._2_face_22.group-shot.jpg
#   inflating: faces/nancy_mace/2_face_28.ap20044800309759.jpg
#   inflating: __MACOSX/faces/nancy_mace/._2_face_28.ap20044800309759.jpg
#   inflating: faces/nancy_mace/3_face_22.group-shot.jpg
#   inflating: __MACOSX/faces/nancy_mace/._3_face_22.group-shot.jpg
#   inflating: faces/nancy_mace/0_face_20.image_asset_101153.jpg
#   inflating: __MACOSX/faces/nancy_mace/._0_face_20.image_asset_101153.jpg
#   inflating: faces/nancy_mace/0_face_25.-1x-1.jpg
#   inflating: __MACOSX/faces/nancy_mace/._0_face_25.-1x-1.jpg
#   inflating: faces/nancy_mace/0_face_5.nancy-mace.jpg
#   inflating: __MACOSX/faces/nancy_mace/._0_face_5.nancy-mace.jpg
#   inflating: faces/nancy_mace/4_face_22.group-shot.jpg
#   inflating: __MACOSX/faces/nancy_mace/._4_face_22.group-shot.jpg
#   inflating: faces/nancy_mace/0_face_12.201217_gma3_nancy_mace_hpmain_16x9_992.jpg
#   inflating: __MACOSX/faces/nancy_mace/._0_face_12.201217_gma3_nancy_mace_hpmain_16x9_992.jpg
#   inflating: faces/nancy_mace/0_face_24.210106_abcnl_prime_mace_hpmain_16x9_992.jpg
#   inflating: __MACOSX/faces/nancy_mace/._0_face_24.210106_abcnl_prime_mace_hpmain_16x9_992.jpg
#   inflating: faces/nancy_mace/0_face_11.5e45dff64b1be.image.jpg
#   inflating: __MACOSX/faces/nancy_mace/._0_face_11.5e45dff64b1be.image.jpg
#   inflating: faces/nancy_mace/0_face_18.u1gweodq.jpg
#   inflating: __MACOSX/faces/nancy_mace/._0_face_18.u1gweodq.jpg
#   inflating: faces/nancy_mace/2_face_8.mace.jpg
#   inflating: __MACOSX/faces/nancy_mace/._2_face_8.mace.jpg
#   inflating: faces/nancy_mace/1_face_25.-1x-1.jpg
#   inflating: __MACOSX/faces/nancy_mace/._1_face_25.-1x-1.jpg
#   inflating: faces/nancy_mace/0_face_2.5f5b95c85d226.image.jpg
#   inflating: __MACOSX/faces/nancy_mace/._0_face_2.5f5b95c85d226.image.jpg
#   inflating: faces/nancy_mace/0_face_16.b5df65fb-49c2-4366-bf44-169208765cd2-large3x4_nancy.jpg
#   inflating: __MACOSX/faces/nancy_mace/._0_face_16.b5df65fb-49c2-4366-bf44-169208765cd2-large3x4_nancy.jpg
#   inflating: faces/nancy_mace/0_face_13.mace-3-780x1024.jpg
#   inflating: __MACOSX/faces/nancy_mace/._0_face_13.mace-3-780x1024.jpg
#   inflating: faces/nancy_mace/0_face_22.group-shot.jpg
#   inflating: __MACOSX/faces/nancy_mace/._0_face_22.group-shot.jpg
#   inflating: faces/nancy_mace/0_face_4.nancy-mace.jpg
#   inflating: __MACOSX/faces/nancy_mace/._0_face_4.nancy-mace.jpg
#   inflating: faces/nancy_mace/0_face_9.c82f22a8-d8ec-4a53-962e-a398303eccec_750x422.jpg
#   inflating: __MACOSX/faces/nancy_mace/._0_face_9.c82f22a8-d8ec-4a53-962e-a398303eccec_750x422.jpg
#   inflating: faces/lloyd_smucker/0_face_21.54b977e839167.hires.jpg
#   inflating: __MACOSX/faces/lloyd_smucker/._0_face_21.54b977e839167.hires.jpg
#   inflating: faces/lloyd_smucker/0_face_14.smucker-and-king-0124-1541526884.jpg
#   inflating: __MACOSX/faces/lloyd_smucker/._0_face_14.smucker-and-king-0124-1541526884.jpg
#   inflating: faces/lloyd_smucker/1_face_10.img_3428%202.jpg
#   inflating: __MACOSX/faces/lloyd_smucker/._1_face_10.img_3428%202.jpg
#   inflating: faces/lloyd_smucker/0_face_25.gettyimages-687804800_toned-1538514530-e1538514700543.jpg
#   inflating: __MACOSX/faces/lloyd_smucker/._0_face_25.gettyimages-687804800_toned-1538514530-e1538514700543.jpg
#   inflating: faces/lloyd_smucker/0_face_28.ar-301149982.jpg%26exactw%3d700%26q%3d80%26exactfit%3dcrop%26rcradius%3d20.jpeg
#   inflating: __MACOSX/faces/lloyd_smucker/._0_face_28.ar-301149982.jpg%26exactw%3d700%26q%3d80%26exactfit%3dcrop%26rcradius%3d20.jpeg
#   inflating: faces/lloyd_smucker/0_face_15.20170327193647002_hd.jpg
#   inflating: __MACOSX/faces/lloyd_smucker/._0_face_15.20170327193647002_hd.jpg
#   inflating: faces/lloyd_smucker/0_face_9.f7e1a00d-583c-4d65-bad6-693142e529f5-large16x9_rep.lloydsmucker.jpg
#   inflating: __MACOSX/faces/lloyd_smucker/._0_face_9.f7e1a00d-583c-4d65-bad6-693142e529f5-large16x9_rep.lloydsmucker.jpg
#   inflating: faces/lloyd_smucker/0_face_8.s001199.jpg
#   inflating: __MACOSX/faces/lloyd_smucker/._0_face_8.s001199.jpg
#   inflating: faces/lloyd_smucker/0_face_19.5bd7733c36d83.image.jpg
#   inflating: __MACOSX/faces/lloyd_smucker/._0_face_19.5bd7733c36d83.image.jpg
#   inflating: faces/lloyd_smucker/0_face_10.img_3428%202.jpg
#   inflating: __MACOSX/faces/lloyd_smucker/._0_face_10.img_3428%202.jpg
#   inflating: faces/lloyd_smucker/1_face_11.smuckerlloyd_120116gn_lead.jpg
#   inflating: __MACOSX/faces/lloyd_smucker/._1_face_11.smuckerlloyd_120116gn_lead.jpg
#   inflating: faces/lloyd_smucker/4_face_10.img_3428%202.jpg
#   inflating: __MACOSX/faces/lloyd_smucker/._4_face_10.img_3428%202.jpg
#   inflating: faces/lloyd_smucker/0_face_5.5cd1e912404e4.image.jpg
#   inflating: __MACOSX/faces/lloyd_smucker/._0_face_5.5cd1e912404e4.image.jpg
#   inflating: faces/lloyd_smucker/0_face_6.ee71fd44-dd23-4d76-a505-51cf5bcaf648-ap_18297753471925.jpg
#   inflating: __MACOSX/faces/lloyd_smucker/._0_face_6.ee71fd44-dd23-4d76-a505-51cf5bcaf648-ap_18297753471925.jpg
#   inflating: faces/lloyd_smucker/0_face_20.whatsapp-image-2021-01-07-at-2.15.59-pm.jpeg
#   inflating: __MACOSX/faces/lloyd_smucker/._0_face_20.whatsapp-image-2021-01-07-at-2.15.59-pm.jpeg
#   inflating: faces/lloyd_smucker/2_face_20.whatsapp-image-2021-01-07-at-2.15.59-pm.jpeg
#   inflating: __MACOSX/faces/lloyd_smucker/._2_face_20.whatsapp-image-2021-01-07-at-2.15.59-pm.jpeg
#   inflating: faces/lloyd_smucker/1_face_13.b88d30a3-c84c-4013-a33b-4bc8f838b708_1920x1080.jpg
#   inflating: __MACOSX/faces/lloyd_smucker/._1_face_13.b88d30a3-c84c-4013-a33b-4bc8f838b708_1920x1080.jpg
#   inflating: faces/lloyd_smucker/2_face_10.img_3428%202.jpg
#   inflating: __MACOSX/faces/lloyd_smucker/._2_face_10.img_3428%202.jpg
#   inflating: faces/lloyd_smucker/0_face_3.s001199.jpg
#   inflating: __MACOSX/faces/lloyd_smucker/._0_face_3.s001199.jpg
#   inflating: faces/lloyd_smucker/0_face_24.lnp.image__0.jpeg
#   inflating: __MACOSX/faces/lloyd_smucker/._0_face_24.lnp.image__0.jpeg
#   inflating: faces/lloyd_smucker/0_face_18.rep-lloyd-smucker-1610110013.jpg
#   inflating: __MACOSX/faces/lloyd_smucker/._0_face_18.rep-lloyd-smucker-1610110013.jpg
#   inflating: faces/lloyd_smucker/0_face_26.cfcf2d6a-757f-4eea-8c6f-bf0de5e45bda-181030_bk_smucker_king_debate_3.jpg
#   inflating: __MACOSX/faces/lloyd_smucker/._0_face_26.cfcf2d6a-757f-4eea-8c6f-bf0de5e45bda-181030_bk_smucker_king_debate_3.jpg
#   inflating: faces/lloyd_smucker/0_face_22.background_1920.jpeg
#   inflating: __MACOSX/faces/lloyd_smucker/._0_face_22.background_1920.jpeg
#   inflating: faces/lloyd_smucker/0_face_2.official%20headshot.jpg
#   inflating: __MACOSX/faces/lloyd_smucker/._0_face_2.official%20headshot.jpg
#   inflating: faces/lloyd_smucker/2_face_17.smuckerswearinginryan.jpg
#   inflating: __MACOSX/faces/lloyd_smucker/._2_face_17.smuckerswearinginryan.jpg
#   inflating: faces/lloyd_smucker/0_face_23.vdbghwy0.jpg
#   inflating: __MACOSX/faces/lloyd_smucker/._0_face_23.vdbghwy0.jpg
#   inflating: faces/lloyd_smucker/0_face_17.smuckerswearinginryan.jpg
#   inflating: __MACOSX/faces/lloyd_smucker/._0_face_17.smuckerswearinginryan.jpg
#   inflating: faces/lloyd_smucker/3_face_20.whatsapp-image-2021-01-07-at-2.15.59-pm.jpeg
#   inflating: __MACOSX/faces/lloyd_smucker/._3_face_20.whatsapp-image-2021-01-07-at-2.15.59-pm.jpeg
#   inflating: faces/lloyd_smucker/0_face_11.smuckerlloyd_120116gn_lead.jpg
#   inflating: __MACOSX/faces/lloyd_smucker/._0_face_11.smuckerlloyd_120116gn_lead.jpg
#   inflating: faces/lloyd_smucker/0_face_1.ls_official_july_2019.jpg
#   inflating: __MACOSX/faces/lloyd_smucker/._0_face_1.ls_official_july_2019.jpg
#   inflating: faces/lloyd_smucker/0_face_29.599f1e4a41914.image.jpg
#   inflating: __MACOSX/faces/lloyd_smucker/._0_face_29.599f1e4a41914.image.jpg
#   inflating: faces/lloyd_smucker/1_face_20.whatsapp-image-2021-01-07-at-2.15.59-pm.jpeg
#   inflating: __MACOSX/faces/lloyd_smucker/._1_face_20.whatsapp-image-2021-01-07-at-2.15.59-pm.jpeg
#   inflating: faces/lloyd_smucker/0_face_7.dl4cnjzx0aa598t.jpg:large.jpg
#   inflating: __MACOSX/faces/lloyd_smucker/._0_face_7.dl4cnjzx0aa598t.jpg:large.jpg
#   inflating: faces/lloyd_smucker/0_face_27.maxresdefault.jpg
#   inflating: __MACOSX/faces/lloyd_smucker/._0_face_27.maxresdefault.jpg
#   inflating: faces/lloyd_smucker/1_face_21.54b977e839167.hires.jpg
#   inflating: __MACOSX/faces/lloyd_smucker/._1_face_21.54b977e839167.hires.jpg
#   inflating: faces/lloyd_smucker/1_face_17.smuckerswearinginryan.jpg
#   inflating: __MACOSX/faces/lloyd_smucker/._1_face_17.smuckerswearinginryan.jpg
#   inflating: faces/lloyd_smucker/0_face_16.g555geuuuzfhpfu33hdmy5wf3y.jpg
#   inflating: __MACOSX/faces/lloyd_smucker/._0_face_16.g555geuuuzfhpfu33hdmy5wf3y.jpg
#   inflating: faces/lloyd_smucker/3_face_10.img_3428%202.jpg
#   inflating: __MACOSX/faces/lloyd_smucker/._3_face_10.img_3428%202.jpg
#   inflating: faces/lloyd_smucker/0_face_13.b88d30a3-c84c-4013-a33b-4bc8f838b708_1920x1080.jpg
#   inflating: __MACOSX/faces/lloyd_smucker/._0_face_13.b88d30a3-c84c-4013-a33b-4bc8f838b708_1920x1080.jpg
#   inflating: faces/lloyd_smucker/1_face_7.dl4cnjzx0aa598t.jpg:large.jpg
#   inflating: __MACOSX/faces/lloyd_smucker/._1_face_7.dl4cnjzx0aa598t.jpg:large.jpg
#   inflating: faces/lloyd_smucker/0_face_4.7906.jpg
#   inflating: __MACOSX/faces/lloyd_smucker/._0_face_4.7906.jpg
#   inflating: faces/lloyd_smucker/1_face_23.vdbghwy0.jpg
#   inflating: __MACOSX/faces/lloyd_smucker/._1_face_23.vdbghwy0.jpg
#   inflating: faces/lloyd_smucker/0_face_12.maxresdefault.jpg
#   inflating: __MACOSX/faces/lloyd_smucker/._0_face_12.maxresdefault.jpg
#   inflating: faces/lloyd_smucker/1_face_14.smucker-and-king-0124-1541526884.jpg
#   inflating: __MACOSX/faces/lloyd_smucker/._1_face_14.smucker-and-king-0124-1541526884.jpg
#   inflating: faces/warren_davidson/0_face_21.web1_appointees-2016-2017-staton.jpg
#   inflating: __MACOSX/faces/warren_davidson/._0_face_21.web1_appointees-2016-2017-staton.jpg
#   inflating: faces/warren_davidson/2_face_11.index.cfm.jpg
#   inflating: __MACOSX/faces/warren_davidson/._2_face_11.index.cfm.jpg
#   inflating: faces/warren_davidson/0_face_8.115_rp_oh_8_davidson_warren_200.jpg
#   inflating: __MACOSX/faces/warren_davidson/._0_face_8.115_rp_oh_8_davidson_warren_200.jpg
#   inflating: faces/warren_davidson/7_face_30.web1_1davidson.jpg
#   inflating: __MACOSX/faces/warren_davidson/._7_face_30.web1_1davidson.jpg
#   inflating: faces/warren_davidson/0_face_24.xuwk2pd4p7t6xlaf6wrpx5kuwq.jpg
#   inflating: __MACOSX/faces/warren_davidson/._0_face_24.xuwk2pd4p7t6xlaf6wrpx5kuwq.jpg
#   inflating: faces/warren_davidson/0_face_1.warren_davidson_congressional_portrait_ca2017.jpg
#   inflating: __MACOSX/faces/warren_davidson/._0_face_1.warren_davidson_congressional_portrait_ca2017.jpg
#   inflating: faces/warren_davidson/0_face_16.warren_davidson_official_congressional_photo_%28cropped%29.jpg
#   inflating: __MACOSX/faces/warren_davidson/._0_face_16.warren_davidson_official_congressional_photo_%28cropped%29.jpg
#   inflating: faces/warren_davidson/0_face_13.io4diuzdwgfgq4kmryowrjthzy.jpg
#   inflating: __MACOSX/faces/warren_davidson/._0_face_13.io4diuzdwgfgq4kmryowrjthzy.jpg
#   inflating: faces/warren_davidson/0_face_30.web1_1davidson.jpg
#   inflating: __MACOSX/faces/warren_davidson/._0_face_30.web1_1davidson.jpg
#   inflating: faces/warren_davidson/5_face_12.gettyimages-539052372.jpg
#   inflating: __MACOSX/faces/warren_davidson/._5_face_12.gettyimages-539052372.jpg
#   inflating: faces/warren_davidson/0_face_11.index.cfm.jpg
#   inflating: __MACOSX/faces/warren_davidson/._0_face_11.index.cfm.jpg
#   inflating: faces/warren_davidson/0_face_2.412675-200px.jpeg
#   inflating: __MACOSX/faces/warren_davidson/._0_face_2.412675-200px.jpeg
#   inflating: faces/warren_davidson/0_face_9.636220934279568551-usp-news-congressional-ceremonial-swearing-in-87772386.jpg
#   inflating: __MACOSX/faces/warren_davidson/._0_face_9.636220934279568551-usp-news-congressional-ceremonial-swearing-in-87772386.jpg
#   inflating: faces/warren_davidson/0_face_15.warren-davidson.jpg
#   inflating: __MACOSX/faces/warren_davidson/._0_face_15.warren-davidson.jpg
#   inflating: faces/warren_davidson/1_face_30.web1_1davidson.jpg
#   inflating: __MACOSX/faces/warren_davidson/._1_face_30.web1_1davidson.jpg
#   inflating: faces/warren_davidson/0_face_18.c2psygi32ihbt64wnsq2op7qtu.jpg
#   inflating: __MACOSX/faces/warren_davidson/._0_face_18.c2psygi32ihbt64wnsq2op7qtu.jpg
#   inflating: faces/warren_davidson/0_face_3.warren_davidson.jpg
#   inflating: __MACOSX/faces/warren_davidson/._0_face_3.warren_davidson.jpg
#   inflating: faces/warren_davidson/1_face_28.web1_davidson-fair-0008-print.jpg
#   inflating: __MACOSX/faces/warren_davidson/._1_face_28.web1_davidson-fair-0008-print.jpg
#   inflating: faces/warren_davidson/4_face_12.gettyimages-539052372.jpg
#   inflating: __MACOSX/faces/warren_davidson/._4_face_12.gettyimages-539052372.jpg
#   inflating: faces/warren_davidson/0_face_7.eisoykyo_400x400.jpg
#   inflating: __MACOSX/faces/warren_davidson/._0_face_7.eisoykyo_400x400.jpg
#   inflating: faces/warren_davidson/6_face_30.web1_1davidson.jpg
#   inflating: __MACOSX/faces/warren_davidson/._6_face_30.web1_1davidson.jpg
#   inflating: faces/warren_davidson/0_face_26..jpg
#   inflating: __MACOSX/faces/warren_davidson/._0_face_26..jpg
#   inflating: faces/warren_davidson/0_face_28.web1_davidson-fair-0008-print.jpg
#   inflating: __MACOSX/faces/warren_davidson/._0_face_28.web1_davidson-fair-0008-print.jpg
#   inflating: faces/warren_davidson/1_face_23.congressman-davidson-final-236x300.jpg
#   inflating: __MACOSX/faces/warren_davidson/._1_face_23.congressman-davidson-final-236x300.jpg
#   inflating: faces/warren_davidson/0_face_4.646b9f78-317e-4004-91f5-092beb32e1a2-davidson.jpg
#   inflating: __MACOSX/faces/warren_davidson/._0_face_4.646b9f78-317e-4004-91f5-092beb32e1a2-davidson.jpg
#   inflating: faces/warren_davidson/3_face_30.web1_1davidson.jpg
#   inflating: __MACOSX/faces/warren_davidson/._3_face_30.web1_1davidson.jpg
#   inflating: faces/warren_davidson/3_face_11.index.cfm.jpg
#   inflating: __MACOSX/faces/warren_davidson/._3_face_11.index.cfm.jpg
#   inflating: faces/warren_davidson/0_face_23.congressman-davidson-final-236x300.jpg
#   inflating: __MACOSX/faces/warren_davidson/._0_face_23.congressman-davidson-final-236x300.jpg
#   inflating: faces/warren_davidson/0_face_20.d000626.jpg
#   inflating: __MACOSX/faces/warren_davidson/._0_face_20.d000626.jpg
#   inflating: faces/warren_davidson/0_face_25.t_48529c3d3e22482caa8949e48eac1eb0_name_t_80987f44955143a69d6945f6688b8ba3_name_congressman_warren_davidson_town_hall_jan__14__2021_.jpg
#   inflating: __MACOSX/faces/warren_davidson/._0_face_25.t_48529c3d3e22482caa8949e48eac1eb0_name_t_80987f44955143a69d6945f6688b8ba3_name_congressman_warren_davidson_town_hall_jan__14__2021_.jpg
#   inflating: faces/warren_davidson/2_face_12.gettyimages-539052372.jpg
#   inflating: __MACOSX/faces/warren_davidson/._2_face_12.gettyimages-539052372.jpg
#   inflating: faces/warren_davidson/0_face_12.gettyimages-539052372.jpg
#   inflating: __MACOSX/faces/warren_davidson/._0_face_12.gettyimages-539052372.jpg
#   inflating: faces/warren_davidson/1_face_5.davidsonwarren_071217gn_lead.jpg
#   inflating: __MACOSX/faces/warren_davidson/._1_face_5.davidsonwarren_071217gn_lead.jpg
#   inflating: faces/warren_davidson/0_face_10.warren_davidson.jpg
#   inflating: __MACOSX/faces/warren_davidson/._0_face_10.warren_davidson.jpg
#   inflating: faces/warren_davidson/1_face_18.c2psygi32ihbt64wnsq2op7qtu.jpg
#   inflating: __MACOSX/faces/warren_davidson/._1_face_18.c2psygi32ihbt64wnsq2op7qtu.jpg
#   inflating: faces/warren_davidson/0_face_5.davidsonwarren_071217gn_lead.jpg
#   inflating: __MACOSX/faces/warren_davidson/._0_face_5.davidsonwarren_071217gn_lead.jpg
#   inflating: faces/warren_davidson/4_face_30.web1_1davidson.jpg
#   inflating: __MACOSX/faces/warren_davidson/._4_face_30.web1_1davidson.jpg
#   inflating: faces/warren_davidson/1_face_11.index.cfm.jpg
#   inflating: __MACOSX/faces/warren_davidson/._1_face_11.index.cfm.jpg
#   inflating: faces/warren_davidson/0_face_14.davidson_bc_125_061318.jpg
#   inflating: __MACOSX/faces/warren_davidson/._0_face_14.davidson_bc_125_061318.jpg
#   inflating: faces/warren_davidson/0_face_27.636275999112657393-davidson2.jpg
#   inflating: __MACOSX/faces/warren_davidson/._0_face_27.636275999112657393-davidson2.jpg
#   inflating: faces/warren_davidson/0_face_19.4tbrgof2ymsm34f65vfbw4xxlm.jpg
#   inflating: __MACOSX/faces/warren_davidson/._0_face_19.4tbrgof2ymsm34f65vfbw4xxlm.jpg
#   inflating: faces/warren_davidson/3_face_12.gettyimages-539052372.jpg
#   inflating: __MACOSX/faces/warren_davidson/._3_face_12.gettyimages-539052372.jpg
#   inflating: faces/warren_davidson/0_face_22.20201120083729001_hd.jpg
#   inflating: __MACOSX/faces/warren_davidson/._0_face_22.20201120083729001_hd.jpg
#   inflating: faces/warren_davidson/5_face_30.web1_1davidson.jpg
#   inflating: __MACOSX/faces/warren_davidson/._5_face_30.web1_1davidson.jpg
#   inflating: faces/warren_davidson/2_face_30.web1_1davidson.jpg
#   inflating: __MACOSX/faces/warren_davidson/._2_face_30.web1_1davidson.jpg
#   inflating: faces/warren_davidson/1_face_12.gettyimages-539052372.jpg
#   inflating: __MACOSX/faces/warren_davidson/._1_face_12.gettyimages-539052372.jpg
#   inflating: faces/warren_davidson/0_face_17.39948388-warren-davidson-ap-jpg.jpg
#   inflating: __MACOSX/faces/warren_davidson/._0_face_17.39948388-warren-davidson-ap-jpg.jpg
#   inflating: faces/warren_davidson/1_face_21.web1_appointees-2016-2017-staton.jpg
#   inflating: __MACOSX/faces/warren_davidson/._1_face_21.web1_appointees-2016-2017-staton.jpg
#   inflating: faces/warren_davidson/1_face_24.xuwk2pd4p7t6xlaf6wrpx5kuwq.jpg
#   inflating: __MACOSX/faces/warren_davidson/._1_face_24.xuwk2pd4p7t6xlaf6wrpx5kuwq.jpg
#   inflating: faces/warren_davidson/2_face_24.xuwk2pd4p7t6xlaf6wrpx5kuwq.jpg
#   inflating: __MACOSX/faces/warren_davidson/._2_face_24.xuwk2pd4p7t6xlaf6wrpx5kuwq.jpg
#   inflating: faces/warren_davidson/2_face_23.congressman-davidson-final-236x300.jpg
#   inflating: __MACOSX/faces/warren_davidson/._2_face_23.congressman-davidson-final-236x300.jpg
#   inflating: faces/warren_davidson/0_face_6.bn-nc579_0316bo_p_20160316091758.jpg
#   inflating: __MACOSX/faces/warren_davidson/._0_face_6.bn-nc579_0316bo_p_20160316091758.jpg
#   inflating: faces/michael_guest/0_face_22.pkvzoetg2njovhvk5abl6bp4zu.png.jpg
#   inflating: __MACOSX/faces/michael_guest/._0_face_22.pkvzoetg2njovhvk5abl6bp4zu.png.jpg
#   inflating: faces/michael_guest/0_face_26.michael-guest-u.s.-congress-e1516299205227.jpg
#   inflating: __MACOSX/faces/michael_guest/._0_face_26.michael-guest-u.s.-congress-e1516299205227.jpg
#   inflating: faces/michael_guest/0_face_5.image%20from%20ios%20-%202019-09-04t135014.019.jpg
#   inflating: __MACOSX/faces/michael_guest/._0_face_5.image%20from%20ios%20-%202019-09-04t135014.019.jpg
#   inflating: faces/michael_guest/3_face_15.eruhogtxkaaj8wn.jpg
#   inflating: __MACOSX/faces/michael_guest/._3_face_15.eruhogtxkaaj8wn.jpg
#   inflating: faces/michael_guest/0_face_14.2kz7b7emgjiifovockxdj6ym54.jpg
#   inflating: __MACOSX/faces/michael_guest/._0_face_14.2kz7b7emgjiifovockxdj6ym54.jpg
#   inflating: faces/michael_guest/0_face_29.154558-881e507d-f7e4-4b07-929e-0a76ef3b8daf.jpg
#   inflating: __MACOSX/faces/michael_guest/._0_face_29.154558-881e507d-f7e4-4b07-929e-0a76ef3b8daf.jpg
#   inflating: faces/michael_guest/0_face_28.154541-97f0337b-3b4e-43a8-b625-c54b242ceb45.jpg
#   inflating: __MACOSX/faces/michael_guest/._0_face_28.154541-97f0337b-3b4e-43a8-b625-c54b242ceb45.jpg
#   inflating: faces/michael_guest/16_face_26.michael-guest-u.s.-congress-e1516299205227.jpg
#   inflating: __MACOSX/faces/michael_guest/._16_face_26.michael-guest-u.s.-congress-e1516299205227.jpg
#   inflating: faces/michael_guest/2_face_28.154541-97f0337b-3b4e-43a8-b625-c54b242ceb45.jpg
#   inflating: __MACOSX/faces/michael_guest/._2_face_28.154541-97f0337b-3b4e-43a8-b625-c54b242ceb45.jpg
#   inflating: faces/michael_guest/2_face_29.154558-881e507d-f7e4-4b07-929e-0a76ef3b8daf.jpg
#   inflating: __MACOSX/faces/michael_guest/._2_face_29.154558-881e507d-f7e4-4b07-929e-0a76ef3b8daf.jpg
#   inflating: faces/michael_guest/4_face_28.154541-97f0337b-3b4e-43a8-b625-c54b242ceb45.jpg
#   inflating: __MACOSX/faces/michael_guest/._4_face_28.154541-97f0337b-3b4e-43a8-b625-c54b242ceb45.jpg
#   inflating: faces/michael_guest/10_face_26.michael-guest-u.s.-congress-e1516299205227.jpg
#   inflating: __MACOSX/faces/michael_guest/._10_face_26.michael-guest-u.s.-congress-e1516299205227.jpg
# ...
#   inflating: faces/john_garamendi/3_face_11.wh%20meeting.jpg
#   inflating: __MACOSX/faces/john_garamendi/._3_face_11.wh%20meeting.jpg
#   inflating: faces/john_garamendi/1_face_19.img_0500.jpg
#   inflating: __MACOSX/faces/john_garamendi/._1_face_19.img_0500.jpg
#   inflating: faces/john_garamendi/0_face_23.garamendi%20carter%20-%20mrr%20innovation%20lab%20uc%20davis.jpg
#   inflating: __MACOSX/faces/john_garamendi/._0_face_23.garamendi%20carter%20-%20mrr%20innovation%20lab%20uc%20davis.jpg
#   inflating: faces/john_garamendi/4_face_19.img_0500.jpg
#   inflating: __MACOSX/faces/john_garamendi/._4_face_19.img_0500.jpg
#   inflating: faces/john_garamendi/0_face_15.20171108080334001_hd.jpg
#   inflating: __MACOSX/faces/john_garamendi/._0_face_15.20171108080334001_hd.jpg
#   inflating: faces/john_garamendi/0_face_14.ca-congressman-garamendi-lindhurst-hs-insights.jpg
#   inflating: __MACOSX/faces/john_garamendi/._0_face_14.ca-congressman-garamendi-lindhurst-hs-insights.jpg
#   inflating: faces/john_garamendi/0_face_17.180919184349-rep-john-garamendi-large-169.jpg
#   inflating: __MACOSX/faces/john_garamendi/._0_face_17.180919184349-rep-john-garamendi-large-169.jpg
#   inflating: faces/john_garamendi/0_face_29.loty_garamendi.jpg
#   inflating: __MACOSX/faces/john_garamendi/._0_face_29.loty_garamendi.jpg
#   inflating: faces/john_garamendi/1_face_16.snapshot-11-1.jpg
#   inflating: __MACOSX/faces/john_garamendi/._1_face_16.snapshot-11-1.jpg
#   inflating: faces/john_garamendi/1_face_25.garamendi.jpeg
#   inflating: __MACOSX/faces/john_garamendi/._1_face_25.garamendi.jpeg
#   inflating: faces/john_garamendi/3_face_27.about-john-2.jpg
#   inflating: __MACOSX/faces/john_garamendi/._3_face_27.about-john-2.jpg
#   inflating: faces/john_garamendi/1_face_30.exq0rubviaiipvf.jpg
#   inflating: __MACOSX/faces/john_garamendi/._1_face_30.exq0rubviaiipvf.jpg
#   inflating: faces/john_garamendi/0_face_2.412382-200px.jpeg
#   inflating: __MACOSX/faces/john_garamendi/._0_face_2.412382-200px.jpeg
#   inflating: faces/john_garamendi/0_face_12.john-garamendi-at-oil-trains-celebration-oct-11-2016-800px.jpg
#   inflating: __MACOSX/faces/john_garamendi/._0_face_12.john-garamendi-at-oil-trains-celebration-oct-11-2016-800px.jpg
#   inflating: faces/john_garamendi/1_face_11.wh%20meeting.jpg
#   inflating: __MACOSX/faces/john_garamendi/._1_face_11.wh%20meeting.jpg
#   inflating: faces/john_garamendi/1_face_20.garamendi_ci_padar.jpg
#   inflating: __MACOSX/faces/john_garamendi/._1_face_20.garamendi_ci_padar.jpg
#   inflating: faces/john_garamendi/0_face_21.congressman_john_garamendi--1024x568.jpg
#   inflating: __MACOSX/faces/john_garamendi/._0_face_21.congressman_john_garamendi--1024x568.jpg
#   inflating: faces/john_garamendi/2_face_23.garamendi%20carter%20-%20mrr%20innovation%20lab%20uc%20davis.jpg
#   inflating: __MACOSX/faces/john_garamendi/._2_face_23.garamendi%20carter%20-%20mrr%20innovation%20lab%20uc%20davis.jpg
#   inflating: faces/john_garamendi/0_face_4.g000559.jpg
#   inflating: __MACOSX/faces/john_garamendi/._0_face_4.g000559.jpg
#   inflating: faces/john_garamendi/0_face_16.snapshot-11-1.jpg
#   inflating: __MACOSX/faces/john_garamendi/._0_face_16.snapshot-11-1.jpg
#   inflating: faces/john_garamendi/2_face_19.img_0500.jpg
#   inflating: __MACOSX/faces/john_garamendi/._2_face_19.img_0500.jpg
#   inflating: faces/john_garamendi/1_face_27.about-john-2.jpg
#   inflating: __MACOSX/faces/john_garamendi/._1_face_27.about-john-2.jpg
#   inflating: faces/john_garamendi/0_face_27.about-john-2.jpg
#   inflating: __MACOSX/faces/john_garamendi/._0_face_27.about-john-2.jpg
#   inflating: faces/john_garamendi/0_face_6.https%3a%2f%2fcdn.cnn.com%2fcnnnext%2fdam%2fassets%2f190628191602-rep-john-garamendi.jpg
#   inflating: __MACOSX/faces/john_garamendi/._0_face_6.https%3a%2f%2fcdn.cnn.com%2fcnnnext%2fdam%2fassets%2f190628191602-rep-john-garamendi.jpg
#   inflating: faces/john_garamendi/0_face_5.20150913-img_3175.jpg
#   inflating: __MACOSX/faces/john_garamendi/._0_face_5.20150913-img_3175.jpg
#   inflating: faces/john_garamendi/4_face_27.about-john-2.jpg
#   inflating: __MACOSX/faces/john_garamendi/._4_face_27.about-john-2.jpg
#   inflating: faces/john_garamendi/0_face_1.john_garamendi_official_photo.jpg
#   inflating: __MACOSX/faces/john_garamendi/._0_face_1.john_garamendi_official_photo.jpg
#   inflating: faces/john_garamendi/0_face_24.210305080205-rep-john-garamendi-0305.jpg
#   inflating: __MACOSX/faces/john_garamendi/._0_face_24.210305080205-rep-john-garamendi-0305.jpg
#   inflating: faces/john_garamendi/0_face_18.20180417073704001_hd.jpg
#   inflating: __MACOSX/faces/john_garamendi/._0_face_18.20180417073704001_hd.jpg
#   inflating: faces/john_garamendi/0_face_20.garamendi_ci_padar.jpg
#   inflating: __MACOSX/faces/john_garamendi/._0_face_20.garamendi_ci_padar.jpg
#   inflating: faces/john_garamendi/4_face_11.wh%20meeting.jpg
#   inflating: __MACOSX/faces/john_garamendi/._4_face_11.wh%20meeting.jpg
#   inflating: faces/john_garamendi/0_face_3.170px-john_garamendi.jpg
#   inflating: __MACOSX/faces/john_garamendi/._0_face_3.170px-john_garamendi.jpg
#   inflating: faces/john_garamendi/0_face_11.wh%20meeting.jpg
#   inflating: __MACOSX/faces/john_garamendi/._0_face_11.wh%20meeting.jpg
#   inflating: faces/john_garamendi/3_face_19.img_0500.jpg
#   inflating: __MACOSX/faces/john_garamendi/._3_face_19.img_0500.jpg
#   inflating: faces/john_garamendi/0_face_10._yzg8amr_400x400.jpg
#   inflating: __MACOSX/faces/john_garamendi/._0_face_10._yzg8amr_400x400.jpg
#   inflating: faces/kevin_cramer/6_face_10.thecramerfamily-32-1.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._6_face_10.thecramerfamily-32-1.jpg
#   inflating: faces/kevin_cramer/4_face_29.senator-kevin-cramer-insulin-award.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._4_face_29.senator-kevin-cramer-insulin-award.jpg
#   inflating: faces/kevin_cramer/2_face_10.thecramerfamily-32-1.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._2_face_10.thecramerfamily-32-1.jpg
#   inflating: faces/kevin_cramer/11_face_10.thecramerfamily-32-1.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._11_face_10.thecramerfamily-32-1.jpg
#   inflating: faces/kevin_cramer/0_face_2.nqwiq0ot_400x400.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._0_face_2.nqwiq0ot_400x400.jpg
#   inflating: faces/kevin_cramer/0_face_23.860563598.jpg.0.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._0_face_23.860563598.jpg.0.jpg
#   inflating: faces/kevin_cramer/2_face_14.800.jpeg
#   inflating: __MACOSX/faces/kevin_cramer/._2_face_14.800.jpeg
#   inflating: faces/kevin_cramer/0_face_20.official_photo3_media.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._0_face_20.official_photo3_media.jpg
#   inflating: faces/kevin_cramer/1_face_29.senator-kevin-cramer-insulin-award.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._1_face_29.senator-kevin-cramer-insulin-award.jpg
#   inflating: faces/kevin_cramer/0_face_7.cramertrump-768x1024.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._0_face_7.cramertrump-768x1024.jpg
#   inflating: faces/kevin_cramer/4_face_12.original.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._4_face_12.original.jpg
#   inflating: faces/kevin_cramer/1_face_12.original.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._1_face_12.original.jpg
#   inflating: faces/kevin_cramer/0_face_18.iukicugtdfltxprmsm737524j4.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._0_face_18.iukicugtdfltxprmsm737524j4.jpg
#   inflating: faces/kevin_cramer/2_face_28.181010_vod_orig_18for18_northdakota_hpmain_16x9_992.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._2_face_28.181010_vod_orig_18for18_northdakota_hpmain_16x9_992.jpg
#   inflating: faces/kevin_cramer/3_face_29.senator-kevin-cramer-insulin-award.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._3_face_29.senator-kevin-cramer-insulin-award.jpg
#   inflating: faces/kevin_cramer/1_face_28.181010_vod_orig_18for18_northdakota_hpmain_16x9_992.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._1_face_28.181010_vod_orig_18for18_northdakota_hpmain_16x9_992.jpg
#   inflating: faces/kevin_cramer/9_face_10.thecramerfamily-32-1.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._9_face_10.thecramerfamily-32-1.jpg
#   inflating: faces/kevin_cramer/1_face_9.cramer%20and%20hoeven.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._1_face_9.cramer%20and%20hoeven.jpg
#   inflating: faces/kevin_cramer/0_face_13.trump1.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._0_face_13.trump1.jpg
#   inflating: faces/kevin_cramer/0_face_15.5fd834422069f400194c7c06.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._0_face_15.5fd834422069f400194c7c06.jpg
#   inflating: faces/kevin_cramer/5_face_12.original.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._5_face_12.original.jpg
#   inflating: faces/kevin_cramer/5_face_10.thecramerfamily-32-1.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._5_face_10.thecramerfamily-32-1.jpg
#   inflating: faces/kevin_cramer/6_face_29.senator-kevin-cramer-insulin-award.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._6_face_29.senator-kevin-cramer-insulin-award.jpg
#   inflating: faces/kevin_cramer/0_face_12.original.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._0_face_12.original.jpg
#   inflating: faces/kevin_cramer/3_face_14.800.jpeg
#   inflating: __MACOSX/faces/kevin_cramer/._3_face_14.800.jpeg
#   inflating: faces/kevin_cramer/12_face_10.thecramerfamily-32-1.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._12_face_10.thecramerfamily-32-1.jpg
#   inflating: faces/kevin_cramer/1_face_10.thecramerfamily-32-1.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._1_face_10.thecramerfamily-32-1.jpg
#   inflating: faces/kevin_cramer/7_face_29.senator-kevin-cramer-insulin-award.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._7_face_29.senator-kevin-cramer-insulin-award.jpg
#   inflating: faces/kevin_cramer/9_face_12.original.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._9_face_12.original.jpg
#   inflating: faces/kevin_cramer/4_face_14.800.jpeg
#   inflating: __MACOSX/faces/kevin_cramer/._4_face_14.800.jpeg
#   inflating: faces/kevin_cramer/0_face_21.qv2mshwj4fdw7b2rgvstzypaye.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._0_face_21.qv2mshwj4fdw7b2rgvstzypaye.jpg
#   inflating: faces/kevin_cramer/3_face_12.original.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._3_face_12.original.jpg
#   inflating: faces/kevin_cramer/0_face_19.1518702579081.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._0_face_19.1518702579081.jpg
#   inflating: faces/kevin_cramer/0_face_26.5f1f4743988ee354085ca018.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._0_face_26.5f1f4743988ee354085ca018.jpg
#   inflating: faces/kevin_cramer/6_face_12.original.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._6_face_12.original.jpg
#   inflating: faces/kevin_cramer/0_face_25.09heitkamp2-superjumbo.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._0_face_25.09heitkamp2-superjumbo.jpg
#   inflating: faces/kevin_cramer/10_face_10.thecramerfamily-32-1.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._10_face_10.thecramerfamily-32-1.jpg
#   inflating: faces/kevin_cramer/3_face_10.thecramerfamily-32-1.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._3_face_10.thecramerfamily-32-1.jpg
#   inflating: faces/kevin_cramer/2_face_29.senator-kevin-cramer-insulin-award.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._2_face_29.senator-kevin-cramer-insulin-award.jpg
#   inflating: faces/kevin_cramer/0_face_22.drfuqiibxfib3aakzvligjiole.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._0_face_22.drfuqiibxfib3aakzvligjiole.jpg
#   inflating: faces/kevin_cramer/0_face_6.170px-kevin_cramer%2c_official_portrait%2c_116th_congress_%28cropped%29.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._0_face_6.170px-kevin_cramer%2c_official_portrait%2c_116th_congress_%28cropped%29.jpg
#   inflating: faces/kevin_cramer/0_face_16.4lkh1kqd_400x400.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._0_face_16.4lkh1kqd_400x400.jpg
#   inflating: faces/kevin_cramer/1_face_13.trump1.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._1_face_13.trump1.jpg
#   inflating: faces/kevin_cramer/0_face_3.399px-kevin_cramer_official_115th_portrait.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._0_face_3.399px-kevin_cramer_official_115th_portrait.jpg
#   inflating: faces/kevin_cramer/0_face_14.800.jpeg
#   inflating: __MACOSX/faces/kevin_cramer/._0_face_14.800.jpeg
#   inflating: faces/kevin_cramer/0_face_5.official_photo4_media.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._0_face_5.official_photo4_media.jpg
#   inflating: faces/kevin_cramer/7_face_10.thecramerfamily-32-1.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._7_face_10.thecramerfamily-32-1.jpg
#   inflating: faces/kevin_cramer/0_face_24..jpg
#   inflating: __MACOSX/faces/kevin_cramer/._0_face_24..jpg
#   inflating: faces/kevin_cramer/0_face_1.kevin_cramer%2c_official_portrait%2c_116th_congress_2.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._0_face_1.kevin_cramer%2c_official_portrait%2c_116th_congress_2.jpg
#   inflating: faces/kevin_cramer/2_face_12.original.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._2_face_12.original.jpg
#   inflating: faces/kevin_cramer/0_face_10.thecramerfamily-32-1.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._0_face_10.thecramerfamily-32-1.jpg
#   inflating: faces/kevin_cramer/0_face_29.senator-kevin-cramer-insulin-award.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._0_face_29.senator-kevin-cramer-insulin-award.jpg
#   inflating: faces/kevin_cramer/7_face_12.original.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._7_face_12.original.jpg
#   inflating: faces/kevin_cramer/8_face_12.original.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._8_face_12.original.jpg
#   inflating: faces/kevin_cramer/3_face_28.181010_vod_orig_18for18_northdakota_hpmain_16x9_992.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._3_face_28.181010_vod_orig_18for18_northdakota_hpmain_16x9_992.jpg
#   inflating: faces/kevin_cramer/4_face_10.thecramerfamily-32-1.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._4_face_10.thecramerfamily-32-1.jpg
#   inflating: faces/kevin_cramer/0_face_8.412555-200px.jpeg
#   inflating: __MACOSX/faces/kevin_cramer/._0_face_8.412555-200px.jpeg
#   inflating: faces/kevin_cramer/0_face_28.181010_vod_orig_18for18_northdakota_hpmain_16x9_992.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._0_face_28.181010_vod_orig_18for18_northdakota_hpmain_16x9_992.jpg
#   inflating: faces/kevin_cramer/1_face_25.09heitkamp2-superjumbo.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._1_face_25.09heitkamp2-superjumbo.jpg
#   inflating: faces/kevin_cramer/0_face_30.senator-kevin-cramer.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._0_face_30.senator-kevin-cramer.jpg
#   inflating: faces/kevin_cramer/5_face_29.senator-kevin-cramer-insulin-award.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._5_face_29.senator-kevin-cramer-insulin-award.jpg
#   inflating: faces/kevin_cramer/0_face_9.cramer%20and%20hoeven.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._0_face_9.cramer%20and%20hoeven.jpg
#   inflating: faces/kevin_cramer/0_face_27.kevin-cramer-senate-donald-trump-impeachment.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._0_face_27.kevin-cramer-senate-donald-trump-impeachment.jpg
#   inflating: faces/kevin_cramer/1_face_7.cramertrump-768x1024.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._1_face_7.cramertrump-768x1024.jpg
#   inflating: faces/kevin_cramer/1_face_14.800.jpeg
#   inflating: __MACOSX/faces/kevin_cramer/._1_face_14.800.jpeg
#   inflating: faces/kevin_cramer/0_face_4.220px-kevin_cramer%2c_official_portrait%2c_113th_congress.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._0_face_4.220px-kevin_cramer%2c_official_portrait%2c_113th_congress.jpg
#   inflating: faces/kevin_cramer/0_face_11.qcpnhqfwtfpndis5tldzsm32jq.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._0_face_11.qcpnhqfwtfpndis5tldzsm32jq.jpg
#   inflating: faces/kevin_cramer/8_face_10.thecramerfamily-32-1.jpg
#   inflating: __MACOSX/faces/kevin_cramer/._8_face_10.thecramerfamily-32-1.jpg

# %% [markdown]
# After you run the code below, click the little folder icon on the left-hand side of the screen. You can browse around and see what files came out of it! You probably need to click the little folder refresh icon, too.

# %% [markdown]
# ## Looking at the images
#
# If you want to look at the images, you can use this code. It picks 16 random ones and displays them in a grid. **If you're feeling lazy, just continue onward without doing it!!!**
#
# ```python
# import glob
# import random
# import matplotlib.pyplot as plt
#
# # Get a list of all files
# filenames = glob.glob("faces/**/*")
#
# # Let's look at them!!!
# plt.figure(figsize=(10, 10))
# for i, filename in enumerate(random.sample(filenames, 16)):
#   ax = plt.subplot(4, 4, i + 1)
#   img = plt.imread(filename)
#   plt.imshow(img)
#   plt.title(filename.split("/")[1])
#   plt.axis("off")
# ```

# %% [markdown]
# # Now, machine learning!
#
# ## Tensorflow setup
#
# Let's start by importing Tensorflow and whatever else we might need.

# %%
import tensorflow as tf
import tensorflow_hub as hub
import matplotlib.pyplot as plt

# %% [markdown]
# So far our images have always been RGB and sized 224x224, so that's what we're going to stick with again. We use 224x224 because the networks we've seen are trained with that size, so it's the only size image they can understand!
#
# > Note: It isn't *all* networks that need 224x224, just the ones we've looked at so far.
#
# **Update `IMAGE_SIZE` to reflect the size image our neural network will want.**

# %%
# Magic numbers for success
IMAGE_SIZE = (224, 224)
IMAGE_SHAPE = IMAGE_SIZE + (3,)

# %% [markdown]
# ## Loading our data
#
# When we did classification in class, we used `tf.keras.preprocessing.image_dataset_from_directory` to, well, load an image dataset from a directory! Since nothing can ever be simple, there are a hundred other ways to do it, too.
#
# This time we're going to use `flow_from_directory` instead. It works almost exactly the same, but it's more efficient if you need to do things like change `0-255` to `0-1` or perform image augmentations to get rotated/zoomed/flipped versions of your photos. Which I guess we do?
#
# **Change `data_dir` to point at to the folder that contains our images.**

# %%
# Magic code for success
data_dir = 'faces'
datagen_kwargs = dict(rescale=1./255, validation_split=.10)
dataflow_kwargs = dict(target_size=IMAGE_SIZE, interpolation="bilinear", class_mode='sparse')

valid_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    **datagen_kwargs)
valid_generator = valid_datagen.flow_from_directory(
    data_dir, subset="validation", shuffle=False, **dataflow_kwargs)

train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rotation_range=5,
    horizontal_flip=True,
    width_shift_range=0.2, height_shift_range=0.2,
    shear_range=0.2, zoom_range=0.2,
    **datagen_kwargs)

train_generator = train_datagen.flow_from_directory(
    data_dir, subset="training", shuffle=True, **dataflow_kwargs)
# Out:
# Found 2777 images belonging to 536 classes.
# Found 27391 images belonging to 536 classes.

# %% [markdown]
# The output should look like this:
#
# ```
# Found 2777 images belonging to 536 classes.
# Found 27391 images belonging to 536 classes.
# ```

# %% [markdown]
# ## Building our model
#
# In class, we tried two approaches to building an image classifier:
#
# 1. Use ImageNet's pre-trained 1,000 categories to figure out what was in images
# 2. Use our own custom network and some custom images we downloaded to train a brand-new model
#
# It turns out there's also a third approach, where you **start with a model that knows about some things, but then you teach it to recognize new things.** This is called **transfer learning.**
#
# Transfer learning is useful because the model probably already knows about color and lines and circles and eyeballs and hair, which is how it knows a dog is different from an airplane. We just say hey, use what you know about color and lines and circles and eyeballs and hair to tell different people apart instead of dogs and planes!
#
# ## Selecting a pre-trained model and architecture
#
# Below you have **three options** of models that you can start from.
#
# 1. **MobileNet:** A network that is optimized for size, and so it's easier to transfer to mobile devices
# 2. **ResNet 50:** A 50-layer residual network
# 3. **ResNet 101:** A 101-layer residual network (like ResNet 50, just bigger)
#
# The difference is the "magic insides" that go between the inputs and the outputs - we don't understand what the insides are, but we still have to make a choice. They've all been trained on ImageNet, so they should in theory all know basically the same stuff.
#
# **Pick a pre-trained model by uncommenting one of the lines below, then running the cell.** If you want, you can read about them by visiting the URL in your browser.

# %%
base_model_url = "https://tfhub.dev/google/imagenet/mobilenet_v2_100_224/feature_vector/4"
# base_model_url = "https://tfhub.dev/tensorflow/resnet_50/feature_vector/1"
# base_model_url = "https://tfhub.dev/google/imagenet/resnet_v2_101/feature_vector/5"

# download the model from 
pretrained_model = hub.KerasLayer(base_model_url, trainable=False)

model = tf.keras.Sequential([
    tf.keras.layers.InputLayer(input_shape=IMAGE_SIZE + (3,)),
    pretrained_model,
    tf.keras.layers.Dropout(rate=0.2),
    tf.keras.layers.Dense(train_generator.num_classes,
                          activation='softmax')
])
model.build((None,)+IMAGE_SIZE+(3,))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# keras_layer (KerasLayer)     (None, 1280)              2257984
# _________________________________________________________________
# dropout (Dropout)            (None, 1280)              0
# _________________________________________________________________
# dense (Dense)                (None, 536)               686616
# =================================================================
# Total params: 2,944,600
# Trainable params: 686,616
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %% [markdown]
# Remember: we're using a **softmax** layer at the end because we want probabilities! Softmax = probabilities!!!

# %% [markdown]
# ## Settings for training our model
#
# Before we train, we need to `.compile` our model. Which I guess is just some sort of setup? It doesn't matter what it is, we just have to do it!!
#
# **Optimizer:** Our optimizer is `adam`, because that's... what people always use. Not *always* always, but since we don't even know what an optimizer is who cares.
#
# **Loss:** We're trying to predict categories, so our loss is either going to be `SparseCategoricalCrossentropy()` or `CategoricalCrossentropy()`. We aren't the first people to be confused about this, so maybe [read this question and answer](https://datascience.stackexchange.com/questions/41921/sparse-categorical-crossentropy-vs-categorical-crossentropy-keras-accuracy) and try the one you think makes the most sense.
#
# **Metrics:** We want to make our classifier accurate, so our metric is... `accuracy`.
#
# **Set the appropriate loss function below.**

# %%
model.compile(
  optimizer='adam', 
  loss=tf.keras.losses.SparseCategoricalCrossentropy(),
  metrics=['accuracy'])

# %% [markdown]
# ## Training the model
#
# Here we go!!! Let's do it!!!
#
# **Pick the number of epochs you want to train for.** It's going to be a tradeoff between accuracy and how long it takes! Right now I have it set for a single epoch, which is definitely not enough.
#
# > If it's taking a really long time to train an epoch (more than 5-10 minutes), we want to make sure you're using the GPU! Click **Runtime** at the top of the screen, then **Change runtime type** and change **Hardware accelerator** to **GPU**. This will make everything faster.
#
# Even though Google Colab will let you run this for up to 12 hours, for this exercise I recommend not going any longer than an hour.

# %%
num_epochs = 4

# This is a little more complicated than in class because we
# are using that 'flow' loader instead of the 'images' loader
steps_per_epoch = train_generator.samples // train_generator.batch_size
validation_steps = valid_generator.samples // valid_generator.batch_size
model.fit(
    train_generator,
    epochs=num_epochs,
    steps_per_epoch=steps_per_epoch,
    validation_data=valid_generator,
    validation_steps=validation_steps)
# Out:
# Epoch 1/4
# 855/855 [==============================] - 349s 367ms/step - loss: 6.7621 - accuracy: 0.0135 - val_loss: 5.5341 - val_accuracy: 0.0592
# Epoch 2/4
# 855/855 [==============================] - 311s 364ms/step - loss: 5.6129 - accuracy: 0.0592 - val_loss: 5.2928 - val_accuracy: 0.0890
# Epoch 3/4
# 855/855 [==============================] - 308s 361ms/step - loss: 5.1877 - accuracy: 0.0972 - val_loss: 5.0205 - val_accuracy: 0.1170
# Epoch 4/4
# 855/855 [==============================] - 311s 364ms/step - loss: 4.9328 - accuracy: 0.1285 - val_loss: 4.9189 - val_accuracy: 0.1403

# %% [markdown]
# ## Your results
#
# How did it do?
#
# `accuracy` is a measure of how good your model is at things it's already seen (e.g. the "train" part of train/test split) and `val_accuracy` is a measure of how good it is at things it *hasn't* seen (e.g. the "test" part of train/test split).
#
# **Paste the last couple line of output into the cell below.** It should look something like this:
#
# ```python
# # Epoch 2/2
# # 855/855 [==============================] - 299s 349ms/step - loss: 5.5293 - accuracy: 0.0758 - val_loss: 5.1483 - val_accuracy: 0.1101
# ```
#
# After pasting, comment them out so it doesn't try to run them!

# %%
# Epoch 1/4
# 855/855 [==============================] - 349s 367ms/step - loss: 6.7621 - accuracy: 0.0135 - val_loss: 5.5341 - val_accuracy: 0.0592
# Epoch 2/4
# 855/855 [==============================] - 311s 364ms/step - loss: 5.6129 - accuracy: 0.0592 - val_loss: 5.2928 - val_accuracy: 0.0890
# Epoch 3/4
# 855/855 [==============================] - 308s 361ms/step - loss: 5.1877 - accuracy: 0.0972 - val_loss: 5.0205 - val_accuracy: 0.1170
# Epoch 4/4
# 855/855 [==============================] - 311s 364ms/step - loss: 4.9328 - accuracy: 0.1285 - val_loss: 4.9189 - val_accuracy: 0.1403

# %% [markdown]
# ## Save your model to Google Drive
#
# Instead of downloading our model, we'll just save it to our Google Drive. Since we don't have a GPU at home (right?? we're on a laptop??), it would probably run too slowly on our machine anyway.

# %%
# Make a new folder called "models" on our drive
# !mkdir -p /content/gdrive/MyDrive/models/face_recognition_v1

# Save the model to that folder
model.save('/content/gdrive/MyDrive/models/face_recognition_v1')
# Out:
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/models/face_recognition_v1/assets
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/models/face_recognition_v1/assets

# %% [markdown]
# We also need to save the names of everyone, because the model only knows numbers! Person 0, Person 1, Person 2, etc.

# %%
class_names = list(train_generator.class_indices.keys())
class_names[:5]
# Out:
# ['a._ferguson',
#  'a._mceachin',
#  'abigail_spanberger',
#  'adam_kinzinger',
#  'adam_schiff']

# %%
import json

with open('/content/gdrive/MyDrive/models/congress_labels.json', 'w') as fp:
  json.dump(class_names, fp)

# %% [markdown]
# # Trying another model
#
# We're going to try another model instead of whatever you picked above. **And this time I'm telling you which one to use.** Our new model is built on ResNet50, but it can't tell a dog from an airplane!
#
# It turns out *there are other image classification datasets out there besides ImageNet!* Some of them are specific to things like cancerous cells or handwritten numbers, but we're going to make use of one that's all about **telling different faces apart.**
#
# There are a lot of options for "standard datasets" for training facial recognition systems. Some are based on random faces from the internet (FaceNet and VGGFace), while others are based on *just celebrities* (CelebNet, which seems kind of weird, honestly). There are probably other ones with mug shots and stuff, too.
#
# VGGFace2 is probably the most popular dataset these days, but I couldn't find a pre-trained VGGFace2 model that could easily work with Tensorflow 2! So instead we're going to use [a ResNet50 trained with FaceNet](https://github.com/nyoki-mtl/keras-facenet) by Hiroki Taniai, adapted for Tensorflow 2 by [Rajan Ghimire](https://github.com/R4j4n/Face-recognition-Using-Facenet-On-Tensorflow-2.X).
#
# In short: **we're using some random face-trained model from the internet instead of one trained on ImageNet.**
#
# ## Defining the model
#
# Once upon a time we wrote our own model. It looked something like this:
#
# ```python
# model = tf.keras.Sequential([
#   tf.keras.layers.experimental.preprocessing.Rescaling(1./255, input_shape=IMAGE_SHAPE),
#   tf.keras.layers.Conv2D(16, 3, padding='same', activation='relu'),
#   tf.keras.layers.MaxPooling2D(),
#   tf.keras.layers.Conv2D(32, 3, padding='same', activation='relu'),
#   tf.keras.layers.MaxPooling2D(),
#   tf.keras.layers.Conv2D(64, 3, padding='same', activation='relu'),
#   tf.keras.layers.MaxPooling2D(),
#   tf.keras.layers.Dropout(0.2),
#   tf.keras.layers.Flatten(),
#   tf.keras.layers.Dense(128, activation='relu'),
#   tf.keras.layers.Dense(len(class_names), activation='softmax')
# ])
# ```
#
# That was a baby model for little babies. In order to use FaceNet, we need to grow up a little!
#
# Our new model is in the cell below. **Run it.**

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, Activation, Input, Add, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, Concatenate, Lambda, add, GlobalAveragePooling2D, Convolution2D, LocallyConnected2D, ZeroPadding2D, concatenate, AveragePooling2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras import backend as K


def scaling(x, scale):
	return x * scale

def InceptionResNetV2():
	inputs = Input(shape=(160, 160, 3))
	x = Conv2D(32, 3, strides=2, padding='valid', use_bias=False, name= 'Conv2d_1a_3x3') (inputs)
	x = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Conv2d_1a_3x3_BatchNorm')(x)
	x = Activation('relu', name='Conv2d_1a_3x3_Activation')(x)
	x = Conv2D(32, 3, strides=1, padding='valid', use_bias=False, name= 'Conv2d_2a_3x3') (x)
	x = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Conv2d_2a_3x3_BatchNorm')(x)
	x = Activation('relu', name='Conv2d_2a_3x3_Activation')(x)
	x = Conv2D(64, 3, strides=1, padding='same', use_bias=False, name= 'Conv2d_2b_3x3') (x)
	x = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Conv2d_2b_3x3_BatchNorm')(x)
	x = Activation('relu', name='Conv2d_2b_3x3_Activation')(x)
	x = MaxPooling2D(3, strides=2, name='MaxPool_3a_3x3')(x)
	x = Conv2D(80, 1, strides=1, padding='valid', use_bias=False, name= 'Conv2d_3b_1x1') (x)
	x = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Conv2d_3b_1x1_BatchNorm')(x)
	x = Activation('relu', name='Conv2d_3b_1x1_Activation')(x)
	x = Conv2D(192, 3, strides=1, padding='valid', use_bias=False, name= 'Conv2d_4a_3x3') (x)
	x = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Conv2d_4a_3x3_BatchNorm')(x)
	x = Activation('relu', name='Conv2d_4a_3x3_Activation')(x)
	x = Conv2D(256, 3, strides=2, padding='valid', use_bias=False, name= 'Conv2d_4b_3x3') (x)
	x = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Conv2d_4b_3x3_BatchNorm')(x)
	x = Activation('relu', name='Conv2d_4b_3x3_Activation')(x)
	
	# 5x Block35 (Inception-ResNet-A block):
	branch_0 = Conv2D(32, 1, strides=1, padding='same', use_bias=False, name= 'Block35_1_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_1_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block35_1_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(32, 1, strides=1, padding='same', use_bias=False, name= 'Block35_1_Branch_1_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_1_Branch_1_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block35_1_Branch_1_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(32, 3, strides=1, padding='same', use_bias=False, name= 'Block35_1_Branch_1_Conv2d_0b_3x3') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_1_Branch_1_Conv2d_0b_3x3_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block35_1_Branch_1_Conv2d_0b_3x3_Activation')(branch_1)
	branch_2 = Conv2D(32, 1, strides=1, padding='same', use_bias=False, name= 'Block35_1_Branch_2_Conv2d_0a_1x1') (x)
	branch_2 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_1_Branch_2_Conv2d_0a_1x1_BatchNorm')(branch_2)
	branch_2 = Activation('relu', name='Block35_1_Branch_2_Conv2d_0a_1x1_Activation')(branch_2)
	branch_2 = Conv2D(32, 3, strides=1, padding='same', use_bias=False, name= 'Block35_1_Branch_2_Conv2d_0b_3x3') (branch_2)
	branch_2 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_1_Branch_2_Conv2d_0b_3x3_BatchNorm')(branch_2)
	branch_2 = Activation('relu', name='Block35_1_Branch_2_Conv2d_0b_3x3_Activation')(branch_2)
	branch_2 = Conv2D(32, 3, strides=1, padding='same', use_bias=False, name= 'Block35_1_Branch_2_Conv2d_0c_3x3') (branch_2)
	branch_2 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_1_Branch_2_Conv2d_0c_3x3_BatchNorm')(branch_2)
	branch_2 = Activation('relu', name='Block35_1_Branch_2_Conv2d_0c_3x3_Activation')(branch_2)
	branches = [branch_0, branch_1, branch_2]
	mixed = Concatenate(axis=3, name='Block35_1_Concatenate')(branches)
	up = Conv2D(256, 1, strides=1, padding='same', use_bias=True, name= 'Block35_1_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.17})(up)
	x = add([x, up])
	x = Activation('relu', name='Block35_1_Activation')(x)
	
	branch_0 = Conv2D(32, 1, strides=1, padding='same', use_bias=False, name= 'Block35_2_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_2_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block35_2_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(32, 1, strides=1, padding='same', use_bias=False, name= 'Block35_2_Branch_1_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_2_Branch_1_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block35_2_Branch_1_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(32, 3, strides=1, padding='same', use_bias=False, name= 'Block35_2_Branch_1_Conv2d_0b_3x3') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_2_Branch_1_Conv2d_0b_3x3_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block35_2_Branch_1_Conv2d_0b_3x3_Activation')(branch_1)
	branch_2 = Conv2D(32, 1, strides=1, padding='same', use_bias=False, name= 'Block35_2_Branch_2_Conv2d_0a_1x1') (x)
	branch_2 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_2_Branch_2_Conv2d_0a_1x1_BatchNorm')(branch_2)
	branch_2 = Activation('relu', name='Block35_2_Branch_2_Conv2d_0a_1x1_Activation')(branch_2)
	branch_2 = Conv2D(32, 3, strides=1, padding='same', use_bias=False, name= 'Block35_2_Branch_2_Conv2d_0b_3x3') (branch_2)
	branch_2 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_2_Branch_2_Conv2d_0b_3x3_BatchNorm')(branch_2)
	branch_2 = Activation('relu', name='Block35_2_Branch_2_Conv2d_0b_3x3_Activation')(branch_2)
	branch_2 = Conv2D(32, 3, strides=1, padding='same', use_bias=False, name= 'Block35_2_Branch_2_Conv2d_0c_3x3') (branch_2)
	branch_2 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_2_Branch_2_Conv2d_0c_3x3_BatchNorm')(branch_2)
	branch_2 = Activation('relu', name='Block35_2_Branch_2_Conv2d_0c_3x3_Activation')(branch_2)
	branches = [branch_0, branch_1, branch_2]
	mixed = Concatenate(axis=3, name='Block35_2_Concatenate')(branches)
	up = Conv2D(256, 1, strides=1, padding='same', use_bias=True, name= 'Block35_2_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.17})(up)
	x = add([x, up])
	x = Activation('relu', name='Block35_2_Activation')(x)
	
	branch_0 = Conv2D(32, 1, strides=1, padding='same', use_bias=False, name= 'Block35_3_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_3_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block35_3_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(32, 1, strides=1, padding='same', use_bias=False, name= 'Block35_3_Branch_1_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_3_Branch_1_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block35_3_Branch_1_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(32, 3, strides=1, padding='same', use_bias=False, name= 'Block35_3_Branch_1_Conv2d_0b_3x3') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_3_Branch_1_Conv2d_0b_3x3_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block35_3_Branch_1_Conv2d_0b_3x3_Activation')(branch_1)
	branch_2 = Conv2D(32, 1, strides=1, padding='same', use_bias=False, name= 'Block35_3_Branch_2_Conv2d_0a_1x1') (x)
	branch_2 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_3_Branch_2_Conv2d_0a_1x1_BatchNorm')(branch_2)
	branch_2 = Activation('relu', name='Block35_3_Branch_2_Conv2d_0a_1x1_Activation')(branch_2)
	branch_2 = Conv2D(32, 3, strides=1, padding='same', use_bias=False, name= 'Block35_3_Branch_2_Conv2d_0b_3x3') (branch_2)
	branch_2 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_3_Branch_2_Conv2d_0b_3x3_BatchNorm')(branch_2)
	branch_2 = Activation('relu', name='Block35_3_Branch_2_Conv2d_0b_3x3_Activation')(branch_2)
	branch_2 = Conv2D(32, 3, strides=1, padding='same', use_bias=False, name= 'Block35_3_Branch_2_Conv2d_0c_3x3') (branch_2)
	branch_2 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_3_Branch_2_Conv2d_0c_3x3_BatchNorm')(branch_2)
	branch_2 = Activation('relu', name='Block35_3_Branch_2_Conv2d_0c_3x3_Activation')(branch_2)
	branches = [branch_0, branch_1, branch_2]
	mixed = Concatenate(axis=3, name='Block35_3_Concatenate')(branches)
	up = Conv2D(256, 1, strides=1, padding='same', use_bias=True, name= 'Block35_3_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.17})(up)
	x = add([x, up])
	x = Activation('relu', name='Block35_3_Activation')(x)
	
	branch_0 = Conv2D(32, 1, strides=1, padding='same', use_bias=False, name= 'Block35_4_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_4_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block35_4_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(32, 1, strides=1, padding='same', use_bias=False, name= 'Block35_4_Branch_1_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_4_Branch_1_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block35_4_Branch_1_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(32, 3, strides=1, padding='same', use_bias=False, name= 'Block35_4_Branch_1_Conv2d_0b_3x3') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_4_Branch_1_Conv2d_0b_3x3_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block35_4_Branch_1_Conv2d_0b_3x3_Activation')(branch_1)
	branch_2 = Conv2D(32, 1, strides=1, padding='same', use_bias=False, name= 'Block35_4_Branch_2_Conv2d_0a_1x1') (x)
	branch_2 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_4_Branch_2_Conv2d_0a_1x1_BatchNorm')(branch_2)
	branch_2 = Activation('relu', name='Block35_4_Branch_2_Conv2d_0a_1x1_Activation')(branch_2)
	branch_2 = Conv2D(32, 3, strides=1, padding='same', use_bias=False, name= 'Block35_4_Branch_2_Conv2d_0b_3x3') (branch_2)
	branch_2 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_4_Branch_2_Conv2d_0b_3x3_BatchNorm')(branch_2)
	branch_2 = Activation('relu', name='Block35_4_Branch_2_Conv2d_0b_3x3_Activation')(branch_2)
	branch_2 = Conv2D(32, 3, strides=1, padding='same', use_bias=False, name= 'Block35_4_Branch_2_Conv2d_0c_3x3') (branch_2)
	branch_2 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_4_Branch_2_Conv2d_0c_3x3_BatchNorm')(branch_2)
	branch_2 = Activation('relu', name='Block35_4_Branch_2_Conv2d_0c_3x3_Activation')(branch_2)
	branches = [branch_0, branch_1, branch_2]
	mixed = Concatenate(axis=3, name='Block35_4_Concatenate')(branches)
	up = Conv2D(256, 1, strides=1, padding='same', use_bias=True, name= 'Block35_4_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.17})(up)
	x = add([x, up])
	x = Activation('relu', name='Block35_4_Activation')(x)
	
	branch_0 = Conv2D(32, 1, strides=1, padding='same', use_bias=False, name= 'Block35_5_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_5_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block35_5_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(32, 1, strides=1, padding='same', use_bias=False, name= 'Block35_5_Branch_1_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_5_Branch_1_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block35_5_Branch_1_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(32, 3, strides=1, padding='same', use_bias=False, name= 'Block35_5_Branch_1_Conv2d_0b_3x3') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_5_Branch_1_Conv2d_0b_3x3_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block35_5_Branch_1_Conv2d_0b_3x3_Activation')(branch_1)
	branch_2 = Conv2D(32, 1, strides=1, padding='same', use_bias=False, name= 'Block35_5_Branch_2_Conv2d_0a_1x1') (x)
	branch_2 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_5_Branch_2_Conv2d_0a_1x1_BatchNorm')(branch_2)
	branch_2 = Activation('relu', name='Block35_5_Branch_2_Conv2d_0a_1x1_Activation')(branch_2)
	branch_2 = Conv2D(32, 3, strides=1, padding='same', use_bias=False, name= 'Block35_5_Branch_2_Conv2d_0b_3x3') (branch_2)
	branch_2 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_5_Branch_2_Conv2d_0b_3x3_BatchNorm')(branch_2)
	branch_2 = Activation('relu', name='Block35_5_Branch_2_Conv2d_0b_3x3_Activation')(branch_2)
	branch_2 = Conv2D(32, 3, strides=1, padding='same', use_bias=False, name= 'Block35_5_Branch_2_Conv2d_0c_3x3') (branch_2)
	branch_2 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_5_Branch_2_Conv2d_0c_3x3_BatchNorm')(branch_2)
	branch_2 = Activation('relu', name='Block35_5_Branch_2_Conv2d_0c_3x3_Activation')(branch_2)
	branches = [branch_0, branch_1, branch_2]
	mixed = Concatenate(axis=3, name='Block35_5_Concatenate')(branches)
	up = Conv2D(256, 1, strides=1, padding='same', use_bias=True, name= 'Block35_5_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.17})(up)
	x = add([x, up])
	x = Activation('relu', name='Block35_5_Activation')(x)

	# Mixed 6a (Reduction-A block):
	branch_0 = Conv2D(384, 3, strides=2, padding='valid', use_bias=False, name= 'Mixed_6a_Branch_0_Conv2d_1a_3x3') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Mixed_6a_Branch_0_Conv2d_1a_3x3_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Mixed_6a_Branch_0_Conv2d_1a_3x3_Activation')(branch_0)
	branch_1 = Conv2D(192, 1, strides=1, padding='same', use_bias=False, name= 'Mixed_6a_Branch_1_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Mixed_6a_Branch_1_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Mixed_6a_Branch_1_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(192, 3, strides=1, padding='same', use_bias=False, name= 'Mixed_6a_Branch_1_Conv2d_0b_3x3') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Mixed_6a_Branch_1_Conv2d_0b_3x3_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Mixed_6a_Branch_1_Conv2d_0b_3x3_Activation')(branch_1)
	branch_1 = Conv2D(256, 3, strides=2, padding='valid', use_bias=False, name= 'Mixed_6a_Branch_1_Conv2d_1a_3x3') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Mixed_6a_Branch_1_Conv2d_1a_3x3_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Mixed_6a_Branch_1_Conv2d_1a_3x3_Activation')(branch_1)
	branch_pool = MaxPooling2D(3, strides=2, padding='valid', name='Mixed_6a_Branch_2_MaxPool_1a_3x3')(x)
	branches = [branch_0, branch_1, branch_pool]
	x = Concatenate(axis=3, name='Mixed_6a')(branches)

	# 10x Block17 (Inception-ResNet-B block):
	branch_0 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_1_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_1_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block17_1_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_1_Branch_1_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_1_Branch_1_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_1_Branch_1_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(128, [1, 7], strides=1, padding='same', use_bias=False, name= 'Block17_1_Branch_1_Conv2d_0b_1x7') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_1_Branch_1_Conv2d_0b_1x7_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_1_Branch_1_Conv2d_0b_1x7_Activation')(branch_1)
	branch_1 = Conv2D(128, [7, 1], strides=1, padding='same', use_bias=False, name= 'Block17_1_Branch_1_Conv2d_0c_7x1') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_1_Branch_1_Conv2d_0c_7x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_1_Branch_1_Conv2d_0c_7x1_Activation')(branch_1)
	branches = [branch_0, branch_1]
	mixed = Concatenate(axis=3, name='Block17_1_Concatenate')(branches)
	up = Conv2D(896, 1, strides=1, padding='same', use_bias=True, name= 'Block17_1_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.1})(up)
	x = add([x, up])
	x = Activation('relu', name='Block17_1_Activation')(x)
	
	branch_0 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_2_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_2_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block17_2_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_2_Branch_2_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_2_Branch_2_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_2_Branch_2_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(128, [1, 7], strides=1, padding='same', use_bias=False, name= 'Block17_2_Branch_2_Conv2d_0b_1x7') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_2_Branch_2_Conv2d_0b_1x7_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_2_Branch_2_Conv2d_0b_1x7_Activation')(branch_1)
	branch_1 = Conv2D(128, [7, 1], strides=1, padding='same', use_bias=False, name= 'Block17_2_Branch_2_Conv2d_0c_7x1') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_2_Branch_2_Conv2d_0c_7x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_2_Branch_2_Conv2d_0c_7x1_Activation')(branch_1)
	branches = [branch_0, branch_1]
	mixed = Concatenate(axis=3, name='Block17_2_Concatenate')(branches)
	up = Conv2D(896, 1, strides=1, padding='same', use_bias=True, name= 'Block17_2_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.1})(up)
	x = add([x, up])
	x = Activation('relu', name='Block17_2_Activation')(x)
	
	branch_0 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_3_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_3_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block17_3_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_3_Branch_3_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_3_Branch_3_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_3_Branch_3_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(128, [1, 7], strides=1, padding='same', use_bias=False, name= 'Block17_3_Branch_3_Conv2d_0b_1x7') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_3_Branch_3_Conv2d_0b_1x7_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_3_Branch_3_Conv2d_0b_1x7_Activation')(branch_1)
	branch_1 = Conv2D(128, [7, 1], strides=1, padding='same', use_bias=False, name= 'Block17_3_Branch_3_Conv2d_0c_7x1') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_3_Branch_3_Conv2d_0c_7x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_3_Branch_3_Conv2d_0c_7x1_Activation')(branch_1)
	branches = [branch_0, branch_1]
	mixed = Concatenate(axis=3, name='Block17_3_Concatenate')(branches)
	up = Conv2D(896, 1, strides=1, padding='same', use_bias=True, name= 'Block17_3_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.1})(up)
	x = add([x, up])
	x = Activation('relu', name='Block17_3_Activation')(x)
	
	branch_0 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_4_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_4_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block17_4_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_4_Branch_4_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_4_Branch_4_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_4_Branch_4_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(128, [1, 7], strides=1, padding='same', use_bias=False, name= 'Block17_4_Branch_4_Conv2d_0b_1x7') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_4_Branch_4_Conv2d_0b_1x7_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_4_Branch_4_Conv2d_0b_1x7_Activation')(branch_1)
	branch_1 = Conv2D(128, [7, 1], strides=1, padding='same', use_bias=False, name= 'Block17_4_Branch_4_Conv2d_0c_7x1') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_4_Branch_4_Conv2d_0c_7x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_4_Branch_4_Conv2d_0c_7x1_Activation')(branch_1)
	branches = [branch_0, branch_1]
	mixed = Concatenate(axis=3, name='Block17_4_Concatenate')(branches)
	up = Conv2D(896, 1, strides=1, padding='same', use_bias=True, name= 'Block17_4_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.1})(up)
	x = add([x, up])
	x = Activation('relu', name='Block17_4_Activation')(x)
	
	branch_0 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_5_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_5_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block17_5_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_5_Branch_5_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_5_Branch_5_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_5_Branch_5_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(128, [1, 7], strides=1, padding='same', use_bias=False, name= 'Block17_5_Branch_5_Conv2d_0b_1x7') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_5_Branch_5_Conv2d_0b_1x7_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_5_Branch_5_Conv2d_0b_1x7_Activation')(branch_1)
	branch_1 = Conv2D(128, [7, 1], strides=1, padding='same', use_bias=False, name= 'Block17_5_Branch_5_Conv2d_0c_7x1') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_5_Branch_5_Conv2d_0c_7x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_5_Branch_5_Conv2d_0c_7x1_Activation')(branch_1)
	branches = [branch_0, branch_1]
	mixed = Concatenate(axis=3, name='Block17_5_Concatenate')(branches)
	up = Conv2D(896, 1, strides=1, padding='same', use_bias=True, name= 'Block17_5_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.1})(up)
	x = add([x, up])
	x = Activation('relu', name='Block17_5_Activation')(x)
	
	branch_0 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_6_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_6_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block17_6_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_6_Branch_6_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_6_Branch_6_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_6_Branch_6_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(128, [1, 7], strides=1, padding='same', use_bias=False, name= 'Block17_6_Branch_6_Conv2d_0b_1x7') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_6_Branch_6_Conv2d_0b_1x7_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_6_Branch_6_Conv2d_0b_1x7_Activation')(branch_1)
	branch_1 = Conv2D(128, [7, 1], strides=1, padding='same', use_bias=False, name= 'Block17_6_Branch_6_Conv2d_0c_7x1') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_6_Branch_6_Conv2d_0c_7x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_6_Branch_6_Conv2d_0c_7x1_Activation')(branch_1)
	branches = [branch_0, branch_1]
	mixed = Concatenate(axis=3, name='Block17_6_Concatenate')(branches)
	up = Conv2D(896, 1, strides=1, padding='same', use_bias=True, name= 'Block17_6_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.1})(up)
	x = add([x, up])
	x = Activation('relu', name='Block17_6_Activation')(x)	
	
	branch_0 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_7_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_7_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block17_7_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_7_Branch_7_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_7_Branch_7_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_7_Branch_7_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(128, [1, 7], strides=1, padding='same', use_bias=False, name= 'Block17_7_Branch_7_Conv2d_0b_1x7') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_7_Branch_7_Conv2d_0b_1x7_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_7_Branch_7_Conv2d_0b_1x7_Activation')(branch_1)
	branch_1 = Conv2D(128, [7, 1], strides=1, padding='same', use_bias=False, name= 'Block17_7_Branch_7_Conv2d_0c_7x1') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_7_Branch_7_Conv2d_0c_7x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_7_Branch_7_Conv2d_0c_7x1_Activation')(branch_1)
	branches = [branch_0, branch_1]
	mixed = Concatenate(axis=3, name='Block17_7_Concatenate')(branches)
	up = Conv2D(896, 1, strides=1, padding='same', use_bias=True, name= 'Block17_7_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.1})(up)
	x = add([x, up])
	x = Activation('relu', name='Block17_7_Activation')(x)
	
	branch_0 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_8_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_8_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block17_8_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_8_Branch_8_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_8_Branch_8_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_8_Branch_8_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(128, [1, 7], strides=1, padding='same', use_bias=False, name= 'Block17_8_Branch_8_Conv2d_0b_1x7') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_8_Branch_8_Conv2d_0b_1x7_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_8_Branch_8_Conv2d_0b_1x7_Activation')(branch_1)
	branch_1 = Conv2D(128, [7, 1], strides=1, padding='same', use_bias=False, name= 'Block17_8_Branch_8_Conv2d_0c_7x1') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_8_Branch_8_Conv2d_0c_7x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_8_Branch_8_Conv2d_0c_7x1_Activation')(branch_1)
	branches = [branch_0, branch_1]
	mixed = Concatenate(axis=3, name='Block17_8_Concatenate')(branches)
	up = Conv2D(896, 1, strides=1, padding='same', use_bias=True, name= 'Block17_8_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.1})(up)
	x = add([x, up])
	x = Activation('relu', name='Block17_8_Activation')(x)
	
	branch_0 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_9_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_9_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block17_9_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_9_Branch_9_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_9_Branch_9_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_9_Branch_9_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(128, [1, 7], strides=1, padding='same', use_bias=False, name= 'Block17_9_Branch_9_Conv2d_0b_1x7') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_9_Branch_9_Conv2d_0b_1x7_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_9_Branch_9_Conv2d_0b_1x7_Activation')(branch_1)
	branch_1 = Conv2D(128, [7, 1], strides=1, padding='same', use_bias=False, name= 'Block17_9_Branch_9_Conv2d_0c_7x1') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_9_Branch_9_Conv2d_0c_7x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_9_Branch_9_Conv2d_0c_7x1_Activation')(branch_1)
	branches = [branch_0, branch_1]
	mixed = Concatenate(axis=3, name='Block17_9_Concatenate')(branches)
	up = Conv2D(896, 1, strides=1, padding='same', use_bias=True, name= 'Block17_9_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.1})(up)
	x = add([x, up])
	x = Activation('relu', name='Block17_9_Activation')(x)
	
	branch_0 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_10_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_10_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block17_10_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_10_Branch_10_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_10_Branch_10_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_10_Branch_10_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(128, [1, 7], strides=1, padding='same', use_bias=False, name= 'Block17_10_Branch_10_Conv2d_0b_1x7') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_10_Branch_10_Conv2d_0b_1x7_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_10_Branch_10_Conv2d_0b_1x7_Activation')(branch_1)
	branch_1 = Conv2D(128, [7, 1], strides=1, padding='same', use_bias=False, name= 'Block17_10_Branch_10_Conv2d_0c_7x1') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_10_Branch_10_Conv2d_0c_7x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_10_Branch_10_Conv2d_0c_7x1_Activation')(branch_1)
	branches = [branch_0, branch_1]
	mixed = Concatenate(axis=3, name='Block17_10_Concatenate')(branches)
	up = Conv2D(896, 1, strides=1, padding='same', use_bias=True, name= 'Block17_10_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.1})(up)
	x = add([x, up])
	x = Activation('relu', name='Block17_10_Activation')(x)

	# Mixed 7a (Reduction-B block): 8 x 8 x 2080	
	branch_0 = Conv2D(256, 1, strides=1, padding='same', use_bias=False, name= 'Mixed_7a_Branch_0_Conv2d_0a_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Mixed_7a_Branch_0_Conv2d_0a_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Mixed_7a_Branch_0_Conv2d_0a_1x1_Activation')(branch_0)
	branch_0 = Conv2D(384, 3, strides=2, padding='valid', use_bias=False, name= 'Mixed_7a_Branch_0_Conv2d_1a_3x3') (branch_0)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Mixed_7a_Branch_0_Conv2d_1a_3x3_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Mixed_7a_Branch_0_Conv2d_1a_3x3_Activation')(branch_0)
	branch_1 = Conv2D(256, 1, strides=1, padding='same', use_bias=False, name= 'Mixed_7a_Branch_1_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Mixed_7a_Branch_1_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Mixed_7a_Branch_1_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(256, 3, strides=2, padding='valid', use_bias=False, name= 'Mixed_7a_Branch_1_Conv2d_1a_3x3') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Mixed_7a_Branch_1_Conv2d_1a_3x3_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Mixed_7a_Branch_1_Conv2d_1a_3x3_Activation')(branch_1)
	branch_2 = Conv2D(256, 1, strides=1, padding='same', use_bias=False, name= 'Mixed_7a_Branch_2_Conv2d_0a_1x1') (x)
	branch_2 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Mixed_7a_Branch_2_Conv2d_0a_1x1_BatchNorm')(branch_2)
	branch_2 = Activation('relu', name='Mixed_7a_Branch_2_Conv2d_0a_1x1_Activation')(branch_2)
	branch_2 = Conv2D(256, 3, strides=1, padding='same', use_bias=False, name= 'Mixed_7a_Branch_2_Conv2d_0b_3x3') (branch_2)
	branch_2 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Mixed_7a_Branch_2_Conv2d_0b_3x3_BatchNorm')(branch_2)
	branch_2 = Activation('relu', name='Mixed_7a_Branch_2_Conv2d_0b_3x3_Activation')(branch_2)
	branch_2 = Conv2D(256, 3, strides=2, padding='valid', use_bias=False, name= 'Mixed_7a_Branch_2_Conv2d_1a_3x3') (branch_2)
	branch_2 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Mixed_7a_Branch_2_Conv2d_1a_3x3_BatchNorm')(branch_2)
	branch_2 = Activation('relu', name='Mixed_7a_Branch_2_Conv2d_1a_3x3_Activation')(branch_2)
	branch_pool = MaxPooling2D(3, strides=2, padding='valid', name='Mixed_7a_Branch_3_MaxPool_1a_3x3')(x)
	branches = [branch_0, branch_1, branch_2, branch_pool]
	x = Concatenate(axis=3, name='Mixed_7a')(branches)

	# 5x Block8 (Inception-ResNet-C block):
	
	branch_0 = Conv2D(192, 1, strides=1, padding='same', use_bias=False, name= 'Block8_1_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_1_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block8_1_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(192, 1, strides=1, padding='same', use_bias=False, name= 'Block8_1_Branch_1_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_1_Branch_1_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block8_1_Branch_1_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(192, [1, 3], strides=1, padding='same', use_bias=False, name= 'Block8_1_Branch_1_Conv2d_0b_1x3') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_1_Branch_1_Conv2d_0b_1x3_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block8_1_Branch_1_Conv2d_0b_1x3_Activation')(branch_1)
	branch_1 = Conv2D(192, [3, 1], strides=1, padding='same', use_bias=False, name= 'Block8_1_Branch_1_Conv2d_0c_3x1') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_1_Branch_1_Conv2d_0c_3x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block8_1_Branch_1_Conv2d_0c_3x1_Activation')(branch_1)
	branches = [branch_0, branch_1]
	mixed = Concatenate(axis=3, name='Block8_1_Concatenate')(branches)
	up = Conv2D(1792, 1, strides=1, padding='same', use_bias=True, name= 'Block8_1_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.2})(up)
	x = add([x, up])
	x = Activation('relu', name='Block8_1_Activation')(x)
	
	branch_0 = Conv2D(192, 1, strides=1, padding='same', use_bias=False, name= 'Block8_2_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_2_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block8_2_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(192, 1, strides=1, padding='same', use_bias=False, name= 'Block8_2_Branch_2_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_2_Branch_2_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block8_2_Branch_2_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(192, [1, 3], strides=1, padding='same', use_bias=False, name= 'Block8_2_Branch_2_Conv2d_0b_1x3') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_2_Branch_2_Conv2d_0b_1x3_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block8_2_Branch_2_Conv2d_0b_1x3_Activation')(branch_1)
	branch_1 = Conv2D(192, [3, 1], strides=1, padding='same', use_bias=False, name= 'Block8_2_Branch_2_Conv2d_0c_3x1') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_2_Branch_2_Conv2d_0c_3x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block8_2_Branch_2_Conv2d_0c_3x1_Activation')(branch_1)
	branches = [branch_0, branch_1]
	mixed = Concatenate(axis=3, name='Block8_2_Concatenate')(branches)
	up = Conv2D(1792, 1, strides=1, padding='same', use_bias=True, name= 'Block8_2_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.2})(up)
	x = add([x, up])
	x = Activation('relu', name='Block8_2_Activation')(x)
	
	branch_0 = Conv2D(192, 1, strides=1, padding='same', use_bias=False, name= 'Block8_3_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_3_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block8_3_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(192, 1, strides=1, padding='same', use_bias=False, name= 'Block8_3_Branch_3_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_3_Branch_3_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block8_3_Branch_3_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(192, [1, 3], strides=1, padding='same', use_bias=False, name= 'Block8_3_Branch_3_Conv2d_0b_1x3') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_3_Branch_3_Conv2d_0b_1x3_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block8_3_Branch_3_Conv2d_0b_1x3_Activation')(branch_1)
	branch_1 = Conv2D(192, [3, 1], strides=1, padding='same', use_bias=False, name= 'Block8_3_Branch_3_Conv2d_0c_3x1') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_3_Branch_3_Conv2d_0c_3x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block8_3_Branch_3_Conv2d_0c_3x1_Activation')(branch_1)
	branches = [branch_0, branch_1]
	mixed = Concatenate(axis=3, name='Block8_3_Concatenate')(branches)
	up = Conv2D(1792, 1, strides=1, padding='same', use_bias=True, name= 'Block8_3_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.2})(up)
	x = add([x, up])
	x = Activation('relu', name='Block8_3_Activation')(x)
	
	branch_0 = Conv2D(192, 1, strides=1, padding='same', use_bias=False, name= 'Block8_4_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_4_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block8_4_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(192, 1, strides=1, padding='same', use_bias=False, name= 'Block8_4_Branch_4_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_4_Branch_4_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block8_4_Branch_4_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(192, [1, 3], strides=1, padding='same', use_bias=False, name= 'Block8_4_Branch_4_Conv2d_0b_1x3') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_4_Branch_4_Conv2d_0b_1x3_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block8_4_Branch_4_Conv2d_0b_1x3_Activation')(branch_1)
	branch_1 = Conv2D(192, [3, 1], strides=1, padding='same', use_bias=False, name= 'Block8_4_Branch_4_Conv2d_0c_3x1') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_4_Branch_4_Conv2d_0c_3x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block8_4_Branch_4_Conv2d_0c_3x1_Activation')(branch_1)
	branches = [branch_0, branch_1]
	mixed = Concatenate(axis=3, name='Block8_4_Concatenate')(branches)
	up = Conv2D(1792, 1, strides=1, padding='same', use_bias=True, name= 'Block8_4_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.2})(up)
	x = add([x, up])
	x = Activation('relu', name='Block8_4_Activation')(x)
	
	branch_0 = Conv2D(192, 1, strides=1, padding='same', use_bias=False, name= 'Block8_5_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_5_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block8_5_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(192, 1, strides=1, padding='same', use_bias=False, name= 'Block8_5_Branch_5_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_5_Branch_5_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block8_5_Branch_5_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(192, [1, 3], strides=1, padding='same', use_bias=False, name= 'Block8_5_Branch_5_Conv2d_0b_1x3') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_5_Branch_5_Conv2d_0b_1x3_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block8_5_Branch_5_Conv2d_0b_1x3_Activation')(branch_1)
	branch_1 = Conv2D(192, [3, 1], strides=1, padding='same', use_bias=False, name= 'Block8_5_Branch_5_Conv2d_0c_3x1') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_5_Branch_5_Conv2d_0c_3x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block8_5_Branch_5_Conv2d_0c_3x1_Activation')(branch_1)
	branches = [branch_0, branch_1]
	mixed = Concatenate(axis=3, name='Block8_5_Concatenate')(branches)
	up = Conv2D(1792, 1, strides=1, padding='same', use_bias=True, name= 'Block8_5_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.2})(up)
	x = add([x, up])
	x = Activation('relu', name='Block8_5_Activation')(x)
	
	branch_0 = Conv2D(192, 1, strides=1, padding='same', use_bias=False, name= 'Block8_6_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_6_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block8_6_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(192, 1, strides=1, padding='same', use_bias=False, name= 'Block8_6_Branch_1_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_6_Branch_1_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block8_6_Branch_1_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(192, [1, 3], strides=1, padding='same', use_bias=False, name= 'Block8_6_Branch_1_Conv2d_0b_1x3') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_6_Branch_1_Conv2d_0b_1x3_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block8_6_Branch_1_Conv2d_0b_1x3_Activation')(branch_1)
	branch_1 = Conv2D(192, [3, 1], strides=1, padding='same', use_bias=False, name= 'Block8_6_Branch_1_Conv2d_0c_3x1') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_6_Branch_1_Conv2d_0c_3x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block8_6_Branch_1_Conv2d_0c_3x1_Activation')(branch_1)
	branches = [branch_0, branch_1]
	mixed = Concatenate(axis=3, name='Block8_6_Concatenate')(branches)
	up = Conv2D(1792, 1, strides=1, padding='same', use_bias=True, name= 'Block8_6_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 1})(up)
	x = add([x, up])
	
	# Classification block
	x = GlobalAveragePooling2D(name='AvgPool')(x)
	x = Dropout(1.0 - 0.8, name='Dropout')(x)
	# Bottleneck
	x = Dense(128, use_bias=False, name='Bottleneck')(x)
	x = BatchNormalization(momentum=0.995, epsilon=0.001, scale=False, name='Bottleneck_BatchNorm')(x)

	# Create model
	model = Model(inputs, x, name='inception_resnet_v1')

	return model

# %% [markdown]
# Fun, right?
#
# To use a pre-trained model, we need two things:
#
# 1. The **model architecture:** what the "magic inside" layers look like, and
# 2. The **model weights:** what the "magic inside" layers learned from training, e.g.
#
# Previously we just pointed Tensorflow at some URL to download all of that info, but now we need to do it manually.
#
# The giant cell above defined the **model architecture** (in this case, ResNet50). Now we need to **give it the pre-trained weights!**
#
# Download `facenet_keras_weights.h5` from CourseWorks or [my Google Drive](https://drive.google.com/file/d/1DCU55aVf93bz7kAYmWrFc1G91-cyf6Js/view?usp=sharing) and upload it to Colab. You should be able to just drag-and-drop into the area to the left of here. You can also upload to Google Drive and use the copy command from up above like we did with `faces.zip` in the very beginning.
#
# After it's done uploading – which might take a while, watch the little circle on the bottom left of the screen – **run the cell below to import the pre-trained weights.**
#
# > If we were very wealthy, had a lot of time, and didn't care about the enviroment, another option would be to download the FaceNet dataset and train our model from scratch. But instead: *we're lazy.*

# %%
# Create the FaceNet model
pretrained_face_model = InceptionResNetV2()

# # Load the weights of the model
pretrained_face_model.load_weights("facenet_keras_weights.h5")
pretrained_face_model.trainable = False

# %% [markdown]
# ## Set up our new model
#
# Now we have our nice new `pretrained_face_encoder`, ready to go!
#
# Last time we built our model, it looked like this:
#
# ```python
# # base_model_url = "https://tfhub.dev/google/imagenet/mobilenet_v2_100_224/feature_vector/4"
# # base_model_url = "https://tfhub.dev/tensorflow/resnet_50/feature_vector/1"
# # base_model_url = "https://tfhub.dev/google/imagenet/resnet_v2_101/feature_vector/5"
#
# # download the model from
# pretrained_model = hub.KerasLayer(base_model_url, trainable=False)
#
# model = tf.keras.Sequential([
#     tf.keras.layers.InputLayer(input_shape=IMAGE_SIZE + (3,)),
#     pretrained_model,
#     tf.keras.layers.Dropout(rate=0.2),
#     tf.keras.layers.Dense(train_generator.num_classes,
#                           activation='softmax')
# ])
# model.build((None,)+IMAGE_SIZE+(3,))
# model.summary()
# ```
#
# **Copy and paste this code into the cell below.**
#
# We'll then need to make **two changes** to use our new model:
#
# 1. Change this code to use the `pretrained_face_model` instead of the model downloaded from tfhub.
# 2. FaceNet didn't use 224x224 images, so we'll need to change `IMAGE_SIZE`. Can you look at the awful, long cell where we defined the architecture to see what the new image size needs to be? *Hint: it's pretty close to the top!*

# %%
# base_model_url = "https://tfhub.dev/google/imagenet/mobilenet_v2_100_224/feature_vector/4"
# base_model_url = "https://tfhub.dev/tensorflow/resnet_50/feature_vector/1"
base_model_url = "https://tfhub.dev/google/imagenet/resnet_v2_101/feature_vector/5"
 
# download the model from 
#pretrained_face_model = InceptionResNetV2()
pretrained_model = hub.KerasLayer(base_model_url, trainable=False)

#  # Magic numbers for success
IMAGE_SIZE = (160, 160)
# IMAGE_SHAPE = IMAGE_SIZE + (3,)

model = tf.keras.Sequential([
    tf.keras.layers.InputLayer(input_shape=IMAGE_SIZE + (3,)),
    pretrained_model,
    tf.keras.layers.Dropout(rate=0.2),
    tf.keras.layers.Dense(train_generator.num_classes,
                          activation='softmax')])
model.build((None,)+IMAGE_SIZE+(3,))
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# keras_layer_1 (KerasLayer)   (None, 2048)              42626560
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 536)               1098264
# =================================================================
# Total params: 43,724,824
# Trainable params: 1,098,264
# Non-trainable params: 42,626,560
# _________________________________________________________________

# %% [markdown]
# ## Compile and train the model
#
# You can copy and paste the same code from the `model.compile` and `model.fit` cells we used before to train this model.
#
# **How many epochs should you use this time?** Feel free to experiment with different numbers.

# %%
# model.compile code goes here
model.compile(
  optimizer='adam', 
  loss=tf.keras.losses.SparseCategoricalCrossentropy(),
  metrics=['accuracy'])

# %%
# num_epochs/fit/etc code goes here
num_epochs = 3 

# This is a little more complicated than in class because we
# are using that 'flow' loader instead of the 'images' loader
steps_per_epoch = train_generator.samples // train_generator.batch_size
validation_steps = valid_generator.samples // valid_generator.batch_size
model.fit(
    train_generator,
    epochs=num_epochs,
    steps_per_epoch=steps_per_epoch,
    validation_data=valid_generator,
    validation_steps=validation_steps)
# Out:
# Epoch 1/3
# 855/855 [==============================] - 373s 428ms/step - loss: 6.7973 - accuracy: 0.0175 - val_loss: 5.3377 - val_accuracy: 0.0850
# Epoch 2/3
# 855/855 [==============================] - 362s 424ms/step - loss: 5.5144 - accuracy: 0.0738 - val_loss: 5.0496 - val_accuracy: 0.1315
# Epoch 3/3
# 855/855 [==============================] - 362s 423ms/step - loss: 5.0261 - accuracy: 0.1177 - val_loss: 4.8898 - val_accuracy: 0.1435

# %% [markdown]
# ## How did it do?
#
# Just like we did before, paste the last epoch result below. Be sure to comment it out!

# %%
# Epoch 1/3
# 855/855 [==============================] - 373s 428ms/step - loss: 6.7973 - accuracy: 0.0175 - val_loss: 5.3377 - val_accuracy: 0.0850
# Epoch 2/3
# 855/855 [==============================] - 362s 424ms/step - loss: 5.5144 - accuracy: 0.0738 - val_loss: 5.0496 - val_accuracy: 0.1315
# Epoch 3/3
# 855/855 [==============================] - 362s 423ms/step - loss: 5.0261 - accuracy: 0.1177 - val_loss: 4.8898 - val_accuracy: 0.1435

# %% [markdown]
# ## Save your model
#
# We'll save this model, too! Our last one was `face_recognition_v1`, so this one can be `face_recognition_v2`.

# %%
# !mkdir -p /content/gdrive/MyDrive/models/face_recognition_v2
model.save('/content/gdrive/MyDrive/models/face_recognition_v2')
# Out:
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/models/face_recognition_v2/assets
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/models/face_recognition_v2/assets
